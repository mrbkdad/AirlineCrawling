# %% [markdown]
# ## 인천 나리타 노선 가격 정보 읽어오기
# - 대상 사이트 : 티웨이 웹사이트

# %% [markdown]
# ### 테웨이 사이트 웹 크롤링
#     - 티웨이 항공권예매 페이지를 이용한 크롤링
#     - 세션을 생성하여 세션을 이용해 HTML 페이지 정보 획득
#     - 필요 데이터 추출 하여 Pandas 의 DataFrame 형태로 생성
#     - 생성된 데이터 엑셀 파일로 저장

# %%
from IPython.display import display
import requests
import pandas as pd
import numpy as np
from pandas import DataFrame
from bs4 import BeautifulSoup
import time
from datetime import datetime
from datetime import timedelta
from common.crawling_util import session_crawling

## 국제선 데이터 조회
def crawling_TW_data(dpt,arr,dpt_date):
    ##출발지, 도착지, 출발일을 기준으로 국내선(국제선) 편도 가격 읽어오기
    print('Crawling twayair homepage schedule site')
    session_url = "https://www.twayair.com/booking/availabilityList.do"
    session_head = {
        'Referer':'https://www.twayair.com/main.do',
    }
    
    url = 'https://www.twayair.com/booking/ajax/searchAvailability.do'
    head = {
        'Referer':'https://www.twayair.com/booking/availabilityList.do',
        'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36'
    }
    param ={
        'origin':dpt,                  'destination':arr,
        'origin1':dpt,                 'destination1':arr,
        'origin2':arr,                 'destination2':dpt,
        'onwardDateStr':dpt_date,      'returnDateStr':dpt_date,
        'today':datetime.today().strftime('%Y%m%d'),
        #'searchAvailId':searchAvailId,
        'travelType':'OW',#'RT',
        'currencyCode':'KRW',            'domesticYn':'N', ## 국제선
        'pointOfPurchase':'KR',          'paxTypeCountStr':'1,0,0',
        'searchType':'byDate',
        'orderByOW':'',               'orderByRT':'',
        'fareBasisCodeOW':'',         'fareBasisCodeRT':'',
        'arrivCntryCode':'',          'promotionCode':'',
    }

    return session_crawling(session_url,url,param,session_head=session_head,head=head,method='get',json=False)

data_heads = ['Flt','start','end','fare1','fare2','fare3','tax1','tax2','seat']
## raw 데이터로 부터 DataFrame 생성
def raw_to_df(raw_data):
    soup = BeautifulSoup(raw_data,'lxml')
    ## 스케줄이 없는 경우 체크
    if len(soup.select('#tbodyOnward tr')[0].select('td')) == 1:
        return None
    
    fare_data = []
    for tr in soup.select('#tbodyOnward tr'):
        td = tr.select('td')
        td_list = [f.text.split()[0].strip() for f in td[:3]]
        ## 1. 이벤트운임에서 항공료만 가져온다.
        fares = [f.attrs['value'] for f in td[3].select('input') if f.attrs['type'] == 'hidden' and f.attrs['name'] == 'fare']
        ## 좌석 체크 하여 매진인 경우 가격 0 처리
        soldout = td[3].select('.txt3')[0].select('.soldout')
        if len(soldout) == 0: #좌석이 많음
            td_list.extend(fares)
        else:
            soldout_txt = soldout[0].text.strip()
            if '매진' in soldout_txt: ## 매진
                td_list.append('0')
            else:
                td_list.extend(fares)
        ## 2. 스마트운임에서 항공료만 가져온다.
        fares = [f.attrs['value'] for f in td[4].select('input') if f.attrs['type'] == 'hidden' and f.attrs['name'] == 'fare']
        ## 좌석 체크 하여 매진인 경우 가격 0 처리
        soldout = td[4].select('.txt3')[0].select('.soldout')
        if len(soldout) == 0: #좌석이 많음
            td_list.extend(fares)
        else:
            soldout_txt = soldout[0].text.strip()
            if '매진' in soldout_txt: ## 매진
                td_list.append('0')
            else:
                td_list.extend(fares)
        ## 3. 일반운잉에서 항공료, 유류세, 공항세를 가져온다.
        fares = [f.attrs['value'] for f in td[5].select('input') 
                 if f.attrs['type'] == 'hidden' and f.attrs['name'] in ['fare','surcharge','tax']]
        ## 좌석 체크 하여 매진인 경우 가격 0 처리
        soldout = td[5].select('.txt3')[0].select('.soldout')
        if len(soldout) == 0: #좌석이 많음
            td_list.extend(fares)
            td_list.append('9')
        else:
            soldout_txt = soldout[0].text.strip()
            if '매진' in soldout_txt: #매진
                td_list.extend(['0','0','0','0'])
            else:
                td_list.extend(fares)
                td_list.append(soldout_txt.replace('(','').replace('석','').replace(')',''))
        fare_data.append(td_list)
    return DataFrame(fare_data,columns=data_heads)

## 하루 기준 가격정보, 텍스정보, 최소값, 최대값, 평균 DataFrame 생성
def read_TW_1day_fare(dpt,arr,dpt_date):
    ## 데이터 읽어오기
    raw_data = crawling_TW_data(dpt,arr,dpt_date)
    df=raw_to_df(raw_data)
    if df is None or len(df) == 0: ## 읽는 도중 에러가 나거나 익셉션 발생으로 문제가 있을 경우 처리
        print('********** No Data Type 1 **********')
        return None

    ## 최소값 최대값 평균 계산
    fare_arr = df[['fare1','fare2','fare3']].values ## fare 만 구해오기
    fare_arr = fare_arr.flatten() # shape 1차원으로 변경
    fare_arr = np.unique(fare_arr)
    if '' in fare_arr or '0' in fare_arr:
        fare_arr = fare_arr[1:] # 0 값 제거
    fare_arr = fare_arr.astype('float') # 중복값 제거, 수치형으로 변경
    ## 요약정보 추가
    df.ix[len(df)] = [dpt_date,'min','max','mean',str(fare_arr.min()),str(fare_arr.max()),str(fare_arr.mean()),'','']
    return df

## 정해진 기간의 데이터 읽어오기, 기본 30일
def read_TW_date_range_fare(dpt,arr,start=0,end=31):
    # 기본 30일간 데이터 읽어서 파일로 저장
    date_range = [ (datetime.today()+timedelta(1)*i).strftime('%Y%m%d') for i in range(start,end)]
    df_list = []
    for d in date_range:
        try:
            fare_df = read_TW_1day_fare(dpt,arr,d)
            if fare_df is not None:
                df_list.append(fare_df)
        except Exception as e:
            print('****** Error occured : ',e)
    result = pd.concat(df_list,ignore_index=True)
    print('++++++++++Total : ', len(result))
    ## 파일 저장
    result.to_excel('{}/{}_{}_{}_{}_{}_{}.xls'.format('excel','TW',dpt,arr,start,end,datetime.today().strftime('%Y%m%d%H%m')))
    return result

# %%
## 하루치 데이터 읽어오기
dpt, arr, dpt_date = 'ICN','NRT','20170425'

df = read_TW_1day_fare(dpt,arr,dpt_date)
df
# Out:
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170425 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170425 , origin:ICN , orderByRT: ,
# End Session crawling
#         Flt  start    end    fare1    fare2     fare3      tax1     tax2 seat
# 0     TW201  07:45  10:15  40800.0  80000.0  280000.0    1100.0  28000.0    9
# 1    TW8201  15:30  18:00  50000.0  80000.0  280000.0    1100.0  28000.0    9
# 2  20170425    min    max     mean  40800.0  280000.0  112700.0

# %%
## 정해진 기간의 데이터 읽어오기
dpt, arr, = 'ICN','NRT'
start,end = 0, 31 ## 읽어올 데이터 기간
read_TW_date_range_fare(dpt,arr,start,end)
# Out:
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170424 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170424 , origin:ICN , orderByRT: ,
# End Session crawling
# ********** No Data Type 1 **********
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170425 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170425 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170426 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170426 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170427 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170427 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170428 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170428 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170429 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170429 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170430 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170430 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170501 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170501 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170502 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170502 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170503 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170503 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170504 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170504 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170505 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170505 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170506 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170506 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170507 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170507 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170508 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170508 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170509 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170509 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170510 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170510 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170511 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170511 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170512 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170512 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170513 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170513 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170514 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170514 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170515 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170515 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170516 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170516 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170517 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170517 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170518 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170518 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170519 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170519 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170520 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170520 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170521 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170521 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170522 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170522 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170523 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170523 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170524 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170524 , origin:ICN , orderByRT: ,
# End Session crawling
# ++++++++++Total :  101
#           Flt  start    end    fare1     fare2     fare3           tax1  \
# 0       TW201  07:45  10:15  40800.0   80000.0  280000.0         1100.0
# 1      TW8201  15:30  18:00  50000.0   80000.0  280000.0         1100.0
# 2    20170425    min    max     mean   40800.0  280000.0       112700.0
# 3       TW201  07:45  10:15  40800.0   80000.0  280000.0         1100.0
# 4      TW8201  15:30  18:00  60000.0   80000.0  280000.0         1100.0
# 5    20170426    min    max     mean   40800.0  280000.0       115200.0
# 6       TW201  07:45  10:15  70000.0   80000.0  280000.0         1100.0
# 7      TW8201  15:30  18:00        0  100000.0  280000.0         1100.0
# 8    20170427    min    max     mean   70000.0  280000.0       132500.0
# 9       TW201  07:45  10:15        0  100000.0  280000.0         1100.0
# 10     TW8201  15:30  18:00        0  110000.0  280000.0         1100.0
# 11   20170428    min    max     mean  100000.0  280000.0  163333.333333
# 12      TW201  07:45  10:15        0         0  280000.0         1100.0
# 13      TW203  11:15  13:25        0  230000.0  280000.0         1100.0
# 14     TW8201  15:30  18:00        0  230000.0  280000.0         1100.0
# 15   20170429    min    max     mean  230000.0  280000.0       255000.0
# 16      TW201  07:45  10:15        0  190000.0  280000.0         1100.0
# 17     TW8201  15:30  18:00        0  190000.0  280000.0         1100.0
# 18   20170430    min    max     mean  190000.0  280000.0       235000.0
# 19      TW201  07:45  10:15        0  120000.0  280000.0         1100.0
# 20     TW8201  15:30  18:00        0  190000.0  280000.0         1100.0
# 21   20170501    min    max     mean  120000.0  280000.0  196666.666667
# 22      TW201  07:45  10:15        0  140000.0  280000.0         1100.0
# 23      TW203  11:15  13:25        0  110000.0  280000.0         1100.0
# 24     TW8201  15:30  18:00        0  190000.0  280000.0         1100.0
# 25   20170502    min    max     mean  110000.0  280000.0       180000.0
# 26      TW201  07:45  10:15        0         0  280000.0         1100.0
# 27     TW8201  15:30  18:00        0         0  280000.0         1100.0
# 28   20170503    min    max     mean  280000.0  280000.0       280000.0
# 29      TW201  07:45  10:15        0  190000.0  280000.0         1100.0
# ..        ...    ...    ...      ...       ...       ...            ...
# 71      TW203  11:15  13:25  70000.0   80000.0  280000.0         1100.0
# 72     TW8201  15:30  18:00        0   90000.0  280000.0         1100.0
# 73   20170516    min    max     mean   70000.0  280000.0       130000.0
# 74      TW201  07:45  10:15        0   80000.0  280000.0         1100.0
# 75     TW8201  15:30  18:00  50000.0   80000.0  280000.0         1100.0
# 76   20170517    min    max     mean   50000.0  280000.0  136666.666667
# 77      TW201  07:45  10:15  70000.0   80000.0  280000.0         1100.0
# 78      TW203  11:15  13:25  70000.0   90000.0  280000.0         1100.0
# 79     TW8201  15:30  18:00        0   90000.0  280000.0         1100.0
# 80   20170518    min    max     mean   70000.0  280000.0       130000.0
# 81      TW201  07:45  10:15        0  100000.0  280000.0         1100.0
# 82     TW8201  15:30  18:00        0  100000.0  280000.0         1100.0
# 83   20170519    min    max     mean  100000.0  280000.0       190000.0
# 84      TW201  07:45  10:15        0  100000.0  280000.0         1100.0
# 85      TW203  11:15  13:25        0   90000.0  280000.0         1100.0
# 86     TW8201  15:30  18:00        0  100000.0  280000.0         1100.0
# 87   20170520    min    max     mean   90000.0  280000.0  156666.666667
# 88      TW201  07:45  10:15  70000.0   80000.0  280000.0         1100.0
# 89     TW8201  15:30  18:00        0  110000.0  280000.0         1100.0
# 90   20170521    min    max     mean   70000.0  280000.0       135000.0
# 91      TW201  07:45  10:15  60000.0   80000.0  280000.0         1100.0
# 92     TW8201  15:30  18:00        0  100000.0  280000.0         1100.0
# 93   20170522    min    max     mean   60000.0  280000.0       130000.0
# 94      TW201  07:45  10:15  60000.0   80000.0  280000.0         1100.0
# 95      TW203  11:15  13:25  60000.0   80000.0  280000.0         1100.0
# 96     TW8201  15:30  18:00        0   80000.0  280000.0         1100.0
# 97   20170523    min    max     mean   60000.0  280000.0       140000.0
# 98      TW201  07:45  10:15  70000.0   80000.0  280000.0         1100.0
# 99     TW8201  15:30  18:00        0  100000.0  280000.0         1100.0
# 100  20170524    min    max     mean   70000.0  280000.0       132500.0
#
#         tax2 seat
# 0    28000.0    9
# 1    28000.0    9
# 2
# 3    28000.0    9
# 4    28000.0    9
# 5
# 6    28000.0    9
# 7    28000.0    9
# 8
# 9    28000.0    9
# 10   28000.0    9
# 11
# 12   28000.0    9
# 13   28000.0    9
# 14   28000.0    2
# 15
# 16   28000.0    9
# 17   28000.0    9
# 18
# 19   28000.0    9
# 20   28000.0    9
# 21
# 22   28000.0    9
# 23   28000.0    9
# 24   28000.0    9
# 25
# 26   28000.0    9
# 27   28000.0    3
# 28
# 29   28000.0    9
# ..       ...  ...
# 71   28000.0    9
# 72   28000.0    9
# 73
# 74   28000.0    9
# 75   28000.0    9
# 76
# 77   28000.0    9
# 78   28000.0    9
# 79   28000.0    9
# 80
# 81   28000.0    9
# 82   28000.0    9
# 83
# 84   28000.0    9
# 85   28000.0    9
# 86   28000.0    9
# 87
# 88   28000.0    9
# 89   28000.0    9
# 90
# 91   28000.0    9
# 92   28000.0    9
# 93
# 94   28000.0    9
# 95   28000.0    9
# 96   28000.0    9
# 97
# 98   28000.0    9
# 99   28000.0    9
# 100
#
# [101 rows x 9 columns]

# %%
## 정해진 기간의 데이터 읽어오기
dpt, arr, = 'ICN','NRT'
start,end = 31, 46 ## 읽어올 데이터 기간
read_TW_date_range_fare(dpt,arr,start,end)
# Out:
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170525 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170525 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170526 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170526 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170527 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170527 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170528 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170528 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170529 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170529 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170530 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170530 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170531 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170531 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170601 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170601 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170602 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170602 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170603 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170603 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170604 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170604 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170605 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170605 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170606 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170606 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170607 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170607 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170608 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170608 , origin:ICN , orderByRT: ,
# End Session crawling
# ++++++++++Total :  52
#          Flt  start    end    fare1     fare2     fare3      tax1     tax2  \
# 0      TW201  07:45  10:15  70000.0   80000.0  280000.0    1100.0  28000.0
# 1      TW203  11:15  13:25  60000.0   90000.0  280000.0    1100.0  28000.0
# 2     TW8201  15:30  18:00        0   80000.0  280000.0    1100.0  28000.0
# 3   20170525    min    max     mean   60000.0  280000.0  116000.0
# 4      TW201  07:45  10:15        0   90000.0  280000.0    1100.0  28000.0
# 5     TW8201  15:30  18:00        0  110000.0  280000.0    1100.0  28000.0
# 6   20170526    min    max     mean   90000.0  280000.0  160000.0
# 7      TW201  07:45  10:15        0   90000.0  280000.0    1100.0  28000.0
# 8      TW203  11:15  13:25  70000.0   80000.0  280000.0    1100.0  28000.0
# 9     TW8201  15:30  18:00        0  100000.0  280000.0    1100.0  28000.0
# 10  20170527    min    max     mean   70000.0  280000.0  124000.0
# 11     TW201  07:45  10:15  60000.0   80000.0  280000.0    1100.0  28000.0
# 12    TW8201  15:30  18:00        0  140000.0  280000.0    1100.0  28000.0
# 13  20170528    min    max     mean   60000.0  280000.0  140000.0
# 14     TW201  07:45  10:15  70000.0   80000.0  280000.0    1100.0  28000.0
# 15    TW8201  15:30  18:00        0  100000.0  280000.0    1100.0  28000.0
# 16  20170529    min    max     mean   70000.0  280000.0  132500.0
# 17     TW201  07:45  10:15  50000.0   80000.0  280000.0    1100.0  28000.0
# 18     TW203  11:15  13:25  50000.0   80000.0  280000.0    1100.0  28000.0
# 19    TW8201  15:30  18:00        0   90000.0  280000.0    1100.0  28000.0
# 20  20170530    min    max     mean   50000.0  280000.0  125000.0
# 21     TW201  07:45  10:15  50000.0   80000.0  280000.0    1100.0  28000.0
# 22    TW8201  15:30  18:00        0  100000.0  280000.0    1100.0  28000.0
# 23  20170531    min    max     mean   50000.0  280000.0  127500.0
# 24     TW201  07:45  10:15        0   80000.0  280000.0    1100.0  28000.0
# 25     TW203  11:15  13:25  70000.0   90000.0  280000.0    1100.0  28000.0
# 26    TW8201  15:30  18:00        0   90000.0  280000.0    1100.0  28000.0
# 27  20170601    min    max     mean   70000.0  280000.0  130000.0
# 28     TW201  07:45  10:15        0  160000.0  280000.0    1100.0  28000.0
# 29    TW8201  15:30  18:00        0  160000.0  280000.0    1100.0  28000.0
# 30  20170602    min    max     mean  160000.0  280000.0  220000.0
# 31     TW201  07:45  10:15        0  230000.0  280000.0    1100.0  28000.0
# 32     TW203  11:15  13:25        0  230000.0  280000.0    1100.0  28000.0
# 33    TW8201  15:30  18:00        0         0  280000.0    1100.0  28000.0
# 34  20170603    min    max     mean  230000.0  280000.0  255000.0
# 35     TW201  07:45  10:15        0  190000.0  280000.0    1100.0  28000.0
# 36    TW8201  15:30  18:00        0  160000.0  280000.0    1100.0  28000.0
# 37  20170604    min    max     mean  160000.0  280000.0  210000.0
# 38     TW201  07:45  10:15  70000.0   80000.0  280000.0    1100.0  28000.0
# 39    TW8201  15:30  18:00        0  110000.0  280000.0    1100.0  28000.0
# 40  20170605    min    max     mean   70000.0  280000.0  135000.0
# 41     TW201  07:45  10:15  60000.0   90000.0  280000.0    1100.0  28000.0
# 42     TW203  11:15  13:25  70000.0   80000.0  280000.0    1100.0  28000.0
# 43    TW8201  15:30  18:00        0   90000.0  280000.0    1100.0  28000.0
# 44  20170606    min    max     mean   60000.0  280000.0  116000.0
# 45     TW201  07:45  10:15  70000.0   80000.0  280000.0    1100.0  28000.0
# 46    TW8201  15:30  18:00        0   90000.0  280000.0    1100.0  28000.0
# 47  20170607    min    max     mean   70000.0  280000.0  130000.0
# 48     TW201  07:45  10:15  50000.0   80000.0  280000.0    1100.0  28000.0
# 49     TW203  11:15  13:25  60000.0   80000.0  280000.0    1100.0  28000.0
# 50    TW8201  15:30  18:00        0   80000.0  280000.0    1100.0  28000.0
# 51  20170608    min    max     mean   50000.0  280000.0  117500.0
#
#    seat
# 0     9
# 1     9
# 2     9
# 3
# 4     9
# 5     9
# 6
# 7     9
# 8     9
# 9     9
# 10
# 11    9
# 12    9
# 13
# 14    9
# 15    9
# 16
# 17    9
# 18    9
# 19    9
# 20
# 21    9
# 22    9
# 23
# 24    9
# 25    9
# 26    9
# 27
# 28    9
# 29    9
# 30
# 31    9
# 32    9
# 33    9
# 34
# 35    9
# 36    9
# 37
# 38    9
# 39    9
# 40
# 41    9
# 42    9
# 43    9
# 44
# 45    9
# 46    9
# 47
# 48    9
# 49    9
# 50    9
# 51

# %%
## 정해진 기간의 데이터 읽어오기
dpt, arr, = 'ICN','NRT'
start,end = 46, 90 ## 읽어올 데이터 기간
read_TW_date_range_fare(dpt,arr,start,end)
# Out:
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170609 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170609 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170610 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170610 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170611 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170611 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170612 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170612 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170613 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170613 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170614 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170614 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170615 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170615 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170616 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170616 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170617 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170617 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170618 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170618 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170619 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170619 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170620 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170620 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170621 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170621 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170622 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170622 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170623 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170623 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170624 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170624 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170625 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170625 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170626 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170626 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170627 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170627 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170628 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170628 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170629 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170629 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170630 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170630 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170701 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170701 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170702 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170702 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170703 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170703 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170704 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170704 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170705 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170705 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170706 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170706 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170707 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170707 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170708 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170708 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170709 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170709 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170710 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170710 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170711 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170711 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170712 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170712 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170713 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170713 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170714 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170714 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170715 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170715 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170716 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170716 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170717 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170717 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170718 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170718 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170719 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170719 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170720 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170720 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170721 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170721 , origin:ICN , orderByRT: ,
# End Session crawling
# Crawling twayair homepage schedule site
# Start Session crawling
# make session :  https://www.twayair.com/booking/availabilityList.do
# crawling :  https://www.twayair.com/booking/ajax/searchAvailability.do
# >> Parameters
# destination:NRT , travelType:OW , domesticYn:N , arrivCntryCode: , currencyCode:KRW , origin1:ICN , searchType:byDate , returnDateStr:20170722 , fareBasisCodeRT: , today:20170424 , orderByOW: , fareBasisCodeOW: , origin2:NRT , destination1:NRT , promotionCode: , pointOfPurchase:KR , destination2:ICN , paxTypeCountStr:1,0,0 , onwardDateStr:20170722 , origin:ICN , orderByRT: ,
# End Session crawling
# ++++++++++Total :  160
#           Flt  start    end    fare1     fare2     fare3           tax1  \
# 0       TW201  07:45  10:15        0  120000.0  280000.0         1100.0
# 1      TW8201  15:30  18:00        0   90000.0  280000.0         1100.0
# 2    20170609    min    max     mean   90000.0  280000.0  163333.333333
# 3       TW201  07:45  10:15        0   80000.0  280000.0         1100.0
# 4       TW203  11:15  13:25        0   90000.0  280000.0         1100.0
# 5      TW8201  15:30  18:00        0   90000.0  280000.0         1100.0
# 6    20170610    min    max     mean   80000.0  280000.0       150000.0
# 7       TW201  07:45  10:15  70000.0   80000.0  280000.0         1100.0
# 8      TW8201  15:30  18:00        0  110000.0  280000.0         1100.0
# 9    20170611    min    max     mean   70000.0  280000.0       135000.0
# 10      TW201  07:45  10:15  70000.0   80000.0  280000.0         1100.0
# 11     TW8201  15:30  18:00        0  120000.0  280000.0         1100.0
# 12   20170612    min    max     mean   70000.0  280000.0       137500.0
# 13      TW201  07:45  10:15  50000.0   80000.0  280000.0         1100.0
# 14      TW203  11:15  13:25  60000.0   80000.0  280000.0         1100.0
# 15     TW8201  15:30  18:00        0   80000.0  280000.0         1100.0
# 16   20170613    min    max     mean   50000.0  280000.0       117500.0
# 17      TW201  07:45  10:15  50000.0   80000.0  280000.0         1100.0
# 18     TW8201  15:30  18:00        0   90000.0  280000.0         1100.0
# 19   20170614    min    max     mean   50000.0  280000.0       125000.0
# 20      TW201  07:45  10:15  50000.0   80000.0  280000.0         1100.0
# 21      TW203  11:15  13:25  60000.0   80000.0  280000.0         1100.0
# 22     TW8201  15:30  18:00        0   90000.0  280000.0         1100.0
# 23   20170615    min    max     mean   50000.0  280000.0       112000.0
# 24      TW201  07:45  10:15        0  100000.0  280000.0         1100.0
# 25     TW8201  15:30  18:00        0  100000.0  280000.0         1100.0
# 26   20170616    min    max     mean  100000.0  280000.0       190000.0
# 27      TW201  07:45  10:15        0  100000.0  280000.0         1100.0
# 28      TW203  11:15  13:25        0   90000.0  280000.0         1100.0
# 29     TW8201  15:30  18:00        0   90000.0  280000.0         1100.0
# ..        ...    ...    ...      ...       ...       ...            ...
# 130     TW201  07:45  10:15        0   90000.0  280000.0         1100.0
# 131    TW8201  15:30  18:00        0  100000.0  280000.0         1100.0
# 132  20170716    min    max     mean   90000.0  280000.0       147500.0
# 133    TW9201  07:15  09:30        0  120000.0  280000.0         1100.0
# 134     TW201  07:45  10:15        0  140000.0  280000.0         1100.0
# 135    TW8201  15:30  18:00        0  160000.0  280000.0         1100.0
# 136  20170717    min    max     mean  120000.0  280000.0       175000.0
# 137    TW9201  07:15  09:30        0  120000.0  280000.0         1100.0
# 138     TW201  07:45  10:15        0   90000.0  280000.0         1100.0
# 139     TW203  11:15  13:25  70000.0   80000.0  280000.0         1100.0
# 140    TW8201  15:30  18:00        0   90000.0  280000.0         1100.0
# 141  20170718    min    max     mean   70000.0  280000.0       128000.0
# 142    TW9201  07:15  09:30        0  120000.0  280000.0         1100.0
# 143     TW201  07:45  10:15        0  100000.0  280000.0         1100.0
# 144    TW8201  15:30  18:00        0   90000.0  280000.0         1100.0
# 145  20170719    min    max     mean   90000.0  280000.0       147500.0
# 146    TW9201  07:15  09:30        0  160000.0  280000.0         1100.0
# 147     TW201  07:45  10:15        0  110000.0  280000.0         1100.0
# 148     TW203  11:15  13:25        0  110000.0  280000.0         1100.0
# 149    TW8201  15:30  18:00        0  110000.0  280000.0         1100.0
# 150  20170720    min    max     mean  110000.0  280000.0  183333.333333
# 151    TW9201  07:15  09:30        0  160000.0  280000.0         1100.0
# 152     TW201  07:45  10:15        0  120000.0  280000.0         1100.0
# 153    TW8201  15:30  18:00        0  120000.0  280000.0         1100.0
# 154  20170721    min    max     mean  120000.0  280000.0  186666.666667
# 155    TW9201  07:15  09:30        0  160000.0  280000.0         1100.0
# 156     TW201  07:45  10:15        0  140000.0  280000.0         1100.0
# 157     TW203  11:15  13:25        0  120000.0  280000.0         1100.0
# 158    TW8201  15:30  18:00        0  140000.0  280000.0         1100.0
# 159  20170722    min    max     mean  120000.0  280000.0       175000.0
#
#         tax2 seat
# 0    28000.0    9
# 1    28000.0    9
# 2
# 3    28000.0    9
# 4    28000.0    9
# 5    28000.0    9
# 6
# 7    28000.0    9
# 8    28000.0    9
# 9
# 10   28000.0    9
# 11   28000.0    9
# 12
# 13   28000.0    9
# 14   28000.0    9
# 15   28000.0    9
# 16
# 17   28000.0    9
# 18   28000.0    9
# 19
# 20   28000.0    9
# 21   28000.0    9
# 22   28000.0    9
# 23
# 24   28000.0    9
# 25   28000.0    9
# 26
# 27   28000.0    9
# 28   28000.0    9
# 29   28000.0    9
# ..       ...  ...
# 130  28000.0    9
# 131  28000.0    9
# 132
# 133  28000.0    9
# 134  28000.0    9
# 135  28000.0    9
# 136
# 137  28000.0    9
# 138  28000.0    9
# 139  28000.0    9
# 140  28000.0    9
# 141
# 142  28000.0    9
# 143  28000.0    9
# 144  28000.0    9
# 145
# 146  28000.0    9
# 147  28000.0    9
# 148  28000.0    9
# 149  28000.0    9
# 150
# 151  28000.0    9
# 152  28000.0    9
# 153  28000.0    9
# 154
# 155  28000.0    9
# 156  28000.0    9
# 157  28000.0    9
# 158  28000.0    9
# 159
#
# [160 rows x 9 columns]
