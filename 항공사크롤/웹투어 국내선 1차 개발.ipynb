# %% [markdown]
# ## 웹투어 국내 노선 가격 정보 읽어오기
# - 검색 기간 : 실시일로부터 1~30일, 31~45일, 46~90일 정보 주기적으로 읽어오기

# %% [markdown]
# ### 웹투어 사이트 웹 크롤링
#     - 웹투어 국내선 실시간항공예약 페이지를 이용한 크롤링
#     - URL : http://www.webtour.com/DA/da__ajx.asp
#     - get 방식, HTML 리턴
#     - 필요 데이터 추출 하여 Pandas 의 DataFrame 형태로 생성
#     - 생성된 데이터 엑셀 파일로 저장

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import time
from common.crawling_util import simple_crawling
from common.parsing_util import stat_fare

## 국내선용 읽어오기
def crawling_WebTour(airline,dpt,arr,dpt_date):
    print('Crawling WebTour domastic schedule site')
    url = 'http://www.webtour.com/DA/da__ajx.asp'
    param = {
        'whereDepCity':dpt,
        'whereArrCity':arr,
        'whereSDate':dpt_date,
        'whereEDate':dpt_date,
        'whereCarCode':airline,
        'cmd':'Ajx_DAir_SetAvaliList_ALL',
        'whereTarget':'daRTBx',           'whereDirection':'',
        'whereItinerary':'oneway',        'whereSeatClass':'All',
        'whereACnt':'1',        'whereCCnt':'0',        'whereICnt':'0',
    }

    return simple_crawling(url,param,method='get',json=False)

## 오늘기준으로 기간의 데이터를 HTML 형태로 raw data dict를 가져온다.
## dict의 키는 (airline code,date)
## airlines는 리스트 형태로 원하는 항공사 코드 정보를 전달한다.
def crawling_WebTour_from_to(airlines,dpt,arr,start=0,end=30):
    # 기본 30일간 데이터 읽어서 HTML 데이터를 리스트로 저장
    date_range = [ (datetime.today()+timedelta(1)*i).strftime('%Y%m%d') for i in range(start,end)]
    raw_data_dict = {} ## (airline code, 날짜)를 키로 가지는 dict 생성
    for d in date_range:
        for acd in airlines:
            try:
                raw_data = crawling_WebTour(acd,dpt,arr,d)
                if raw_data is not None:
                    raw_data_dict[(acd,d)]=raw_data
            except Exception as e:
                print('****** Error occured : ',e)
        time.sleep(2) ## 지연고려 sleep
    print('Crawling Total Result : ', len(raw_data_dict))
    return raw_data_dict

    
## 국제선용 데이터 파싱, HRML 데이터 파싱 처리
def make_raw_data_to_list(raw_data):
    soup = BeautifulSoup(raw_data,'lxml')
    fare_list = []
    for fare in soup.select('.daLeftBxUlAll'):
        fare_list.append([fare.select('.flight em')[0].text,fare.select('.time em')[0].text,fare.select('.seat')[0].text,
              fare.select('.fare em')[0].text,fare.select('.num em')[0].text])
    return fare_list


## 하루치 raw 데이터를 리스트로 변경한 데이터를 DataFrame으로 변경
def make_raw_list_to_df(airline,dpt_date,raw_list):
    '''
    1. raw_data 루프 처리
    2. 일간 최소값, 최고값, 평균값 계산
    3. DataFrame 최종 concat
    4. 파일 생성
    5. DataFrame 리턴
    '''
    data_header = ['airline','dpt_date','flt','dpt','arr','type','fare','seat']
    result_header = ['airline','dpt_date','flt','dpt','arr','fare1','fare2','fare3','seat']
    result_list = []
    for pos,r_list in enumerate(raw_list):
        #print(pos)
        result_list.append([airline,dpt_date,r_list[0],r_list[1][:5].replace(':',''),r_list[1][6:].replace(':',''),
                   r_list[2],r_list[3][:-1].replace(',',''),r_list[4]])
    ## 1차 DataFrame 생성
    df = pd.DataFrame(result_list,columns=data_header)
    ## 특가석, 할인석이 없는 데이터에 대해 임의의 로우 추가
    if '특가석' not in df['type'].values:
        ix = len(df)
        df.ix[ix] = df.ix[ix-1]
        df.ix[ix]['type','fare','seat'] = ['특가석','0','0']
    if '할인석' not in df['type'].values:
        ix = len(df)
        df.ix[ix] = df.ix[ix-1]
        df.ix[ix]['type','fare','seat'] = ['할인석','0','0']
    ## 각편의 일반석, 할인석이 별도의 로우로 되어 있어 하나의 로우로 groupby
    df_group=df.groupby(data_header[:6]).sum()
    df_group = df_group.unstack(fill_value='0')
    ## 헤더 조정, 그룹화 후 일반석, 할인석 순서로 정렬되기 때문에 아래와 같이 조정
    df_group.columns = ['fare3','fare1','fare2','seat','seat1','seat2']
    ## 일반석의 좌석이 있는 부분만 추출, 체크 필요
    df_group = df_group[df_group['seat']!='0']
    result=df_group.reset_index()[result_header]
    if len(result) > 0:
        ## 가격 통계라인 추가
        fare_stat = stat_fare(result,columns=['fare1','fare2','fare3'])
        result.ix[len(result)] = [airline,dpt_date,'min','max','mean',
                                  str(fare_stat[0]),str(fare_stat[1]),str(fare_stat[2]),'']
    return result

## 기간 raw 데이터 리스트를 DataFrame 으로 변경 및 저장 처리
def make_raw_data_dict_to_df(dpt,arr,start,end,raw_data_dict):
    df_list = []
    for k,raw_data in raw_data_dict.items():
        #print(k)
        raw_list = make_raw_data_to_list(raw_data)
        if len(raw_list) == 0: ## 읽어온 데이터가 없을 경우, 지연현상이나 여러가지 이유로
            print('********** Data Not Found! pos - {}**********'.format(k))
            continue
        raw_df = make_raw_list_to_df(*k,raw_list)
        if len(raw_df) == 0: ## 읽어온 데이터가 없을 경우, 지연현상이나 여러가지 이유로
            print('********** Data Not Found! pos - {}**********'.format(k))
            continue
        df_list.append(raw_df)
    result_df = pd.concat(df_list,ignore_index=True)
    result_df.to_excel('{}/{}_{}_{}_{}_{}_{}.xls'.format('excel','WebTour',dpt,arr,start,end,datetime.today().strftime('%Y%m%d%H%M')))
    return result_df

# %%
## 국내선 1일 데이터 읽어오기
dpt, arr, dpt_date, airlines = 'GMP','CJU','20170705','7C'
raw_data = crawling_WebTour(airlines,dpt,arr,dpt_date)
raw_list= make_raw_data_to_list(raw_data)
df=make_raw_list_to_df(airlines,dpt_date,raw_list)
df.tail()
# Out:
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170705 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170705 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
#    airline  dpt_date    flt   dpt   arr    fare1    fare2    fare3 seat
# 16      7C  20170705  7C145  1645  1755    26100        0    71800    9
# 17      7C  20170705  7C147  2025  2135    26100        0    71800    9
# 18      7C  20170705  7C151  0625  0730        0    35100    71800    9
# 19      7C  20170705  7C155  1525  1640        0    29100    71800    9
# 20      7C  20170705    min   max  mean  26100.0  71800.0  42400.0

# %%
## 국제선 기간 데이터 읽어오기
dpt, arr, airlines = 'GMP','CJU',['7C','TW','ZE','LJ','BX']
start, end = 1,31
raw_data_dict = crawling_WebTour_from_to(airlines,dpt,arr,start=start,end=end)

df = make_raw_data_dict_to_df(dpt,arr,start,end,raw_data_dict)
df.head()
# Out:
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170426 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170426 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170426 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170426 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170426 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170426 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170426 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170426 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170426 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170426 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170427 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170427 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170427 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170427 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170427 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170427 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170427 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170427 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170427 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170427 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170428 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170428 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170428 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170428 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170428 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170428 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170428 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170428 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170428 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170428 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170429 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170429 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170429 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170429 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170429 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170429 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170429 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170429 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170429 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170429 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170430 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170430 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170430 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170430 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170430 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170430 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170430 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170430 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170430 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170430 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170501 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170501 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170501 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170501 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170501 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170501 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170501 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170501 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170501 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170501 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170502 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170502 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170502 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170502 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170502 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170502 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170502 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170502 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170502 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170502 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170503 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170503 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170503 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170503 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170503 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170503 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170503 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170503 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170503 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170503 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170504 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170504 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170504 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170504 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170504 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170504 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170504 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170504 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170504 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170504 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170505 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170505 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170505 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170505 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170505 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170505 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170505 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170505 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170505 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170505 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170506 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170506 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170506 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170506 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170506 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170506 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170506 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170506 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170506 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170506 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170507 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170507 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170507 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170507 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170507 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170507 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170507 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170507 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170507 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170507 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170508 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170508 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170508 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170508 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170508 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170508 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170508 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170508 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170508 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170508 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170509 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170509 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170509 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170509 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170509 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170509 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170509 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170509 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170509 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170509 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170510 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170510 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170510 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170510 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170510 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170510 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170510 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170510 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170510 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170510 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170511 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170511 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170511 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170511 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170511 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170511 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170511 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170511 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170511 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170511 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170512 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170512 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170512 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170512 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170512 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170512 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170512 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170512 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170512 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170512 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170513 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170513 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170513 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170513 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170513 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170513 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170513 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170513 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170513 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170513 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170514 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170514 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170514 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170514 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170514 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170514 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170514 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170514 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170514 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170514 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170515 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170515 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170515 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170515 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170515 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170515 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170515 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170515 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170515 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170515 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170516 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170516 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170516 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170516 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170516 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170516 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170516 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170516 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170516 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170516 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170517 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170517 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170517 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170517 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170517 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170517 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170517 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170517 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170517 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170517 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170518 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170518 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170518 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170518 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170518 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170518 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170518 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170518 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170518 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170518 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170519 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170519 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170519 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170519 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170519 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170519 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170519 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170519 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170519 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170519 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170520 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170520 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170520 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170520 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170520 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170520 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170520 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170520 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170520 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170520 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170521 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170521 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170521 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170521 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170521 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170521 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170521 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170521 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170521 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170521 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170522 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170522 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170522 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170522 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170522 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170522 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170522 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170522 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170522 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170522 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170523 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170523 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170523 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170523 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170523 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170523 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170523 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170523 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170523 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170523 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170524 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170524 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170524 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170524 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170524 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170524 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170524 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170524 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170524 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170524 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170525 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170525 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170525 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170525 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170525 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170525 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170525 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170525 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170525 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170525 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling Total Result :  150
# ('ZE', '20170524')
# ('ZE', '20170428')
# ('ZE', '20170513')
# ('ZE', '20170509')
# ('TW', '20170524')
# ('LJ', '20170501')
# ('ZE', '20170519')
# ('BX', '20170428')
# ********** Data Not Found! pos - ('BX', '20170428')**********
# ('ZE', '20170514')
# ('BX', '20170511')
# ('7C', '20170426')
# ('7C', '20170430')
# ('LJ', '20170427')
# ('ZE', '20170523')
# ('BX', '20170521')
# ('TW', '20170516')
# ('ZE', '20170503')
# ('TW', '20170503')
# ********** Data Not Found! pos - ('TW', '20170503')**********
# ('ZE', '20170521')
# ('LJ', '20170512')
# ('BX', '20170516')
# ('BX', '20170515')
# ('TW', '20170512')
# ('LJ', '20170518')
# ('BX', '20170524')
# ('BX', '20170519')
# ('TW', '20170514')
# ('BX', '20170426')
# ('TW', '20170427')
# ('LJ', '20170519')
# ('ZE', '20170525')
# ('TW', '20170505')
# ('7C', '20170427')
# ('TW', '20170521')
# ('7C', '20170508')
# ('BX', '20170509')
# ('ZE', '20170510')
# ('BX', '20170507')
# ('7C', '20170523')
# ('7C', '20170512')
# ('BX', '20170504')
# ('7C', '20170521')
# ('LJ', '20170514')
# ('ZE', '20170504')
# ('BX', '20170522')
# ('ZE', '20170427')
# ('7C', '20170516')
# ('7C', '20170502')
# ('7C', '20170507')
# ('LJ', '20170505')
# ('LJ', '20170508')
# ('7C', '20170518')
# ('LJ', '20170516')
# ('LJ', '20170524')
# ('BX', '20170520')
# ('ZE', '20170508')
# ('7C', '20170511')
# ('7C', '20170504')
# ('TW', '20170501')
# ('7C', '20170514')
# ('BX', '20170518')
# ('BX', '20170502')
# ('7C', '20170515')
# ('LJ', '20170503')
# ('BX', '20170508')
# ('7C', '20170513')
# ('TW', '20170510')
# ('LJ', '20170507')
# ('TW', '20170515')
# ('7C', '20170503')
# ********** Data Not Found! pos - ('7C', '20170503')**********
# ('7C', '20170517')
# ('ZE', '20170502')
# ('TW', '20170525')
# ('TW', '20170428')
# ('LJ', '20170522')
# ('BX', '20170513')
# ('TW', '20170426')
# ('LJ', '20170511')
# ('7C', '20170509')
# ('LJ', '20170504')
# ('7C', '20170520')
# ('TW', '20170509')
# ('TW', '20170506')
# ('TW', '20170430')
# ********** Data Not Found! pos - ('TW', '20170430')**********
# ('ZE', '20170516')
# ('ZE', '20170515')
# ('7C', '20170506')
# ('LJ', '20170429')
# ********** Data Not Found! pos - ('LJ', '20170429')**********
# ('LJ', '20170517')
# ('7C', '20170525')
# ('7C', '20170524')
# ('TW', '20170518')
# ('ZE', '20170520')
# ('TW', '20170508')
# ('BX', '20170429')
# ********** Data Not Found! pos - ('BX', '20170429')**********
# ('TW', '20170523')
# ('7C', '20170501')
# ('TW', '20170517')
# ('LJ', '20170428')
# ('ZE', '20170507')
# ('7C', '20170505')
# ('LJ', '20170513')
# ('LJ', '20170502')
# ('LJ', '20170430')
# ('ZE', '20170429')
# ********** Data Not Found! pos - ('ZE', '20170429')**********
# ('ZE', '20170522')
# ('BX', '20170512')
# ('ZE', '20170426')
# ('BX', '20170514')
# ('TW', '20170511')
# ('ZE', '20170511')
# ('TW', '20170502')
# ('BX', '20170427')
# ('BX', '20170510')
# ('BX', '20170505')
# ('BX', '20170503')
# ********** Data Not Found! pos - ('BX', '20170503')**********
# ('TW', '20170520')
# ('LJ', '20170520')
# ('LJ', '20170515')
# ('TW', '20170507')
# ('ZE', '20170501')
# ('ZE', '20170517')
# ('TW', '20170519')
# ('ZE', '20170505')
# ('7C', '20170429')
# ********** Data Not Found! pos - ('7C', '20170429')**********
# ('LJ', '20170506')
# ('7C', '20170522')
# ('LJ', '20170523')
# ('7C', '20170510')
# ('BX', '20170506')
# ('BX', '20170525')
# ('LJ', '20170521')
# ('ZE', '20170512')
# ********** Data Not Found! pos - ('ZE', '20170512')**********
# ('LJ', '20170509')
# ('7C', '20170428')
# ********** Data Not Found! pos - ('7C', '20170428')**********
# ('BX', '20170523')
# ('TW', '20170504')
# ('ZE', '20170430')
# ('ZE', '20170506')
# ('LJ', '20170426')
# ('TW', '20170429')
# ********** Data Not Found! pos - ('TW', '20170429')**********
# ('7C', '20170519')
# ('TW', '20170522')
# ('TW', '20170513')
# ('LJ', '20170525')
# ('BX', '20170430')
# ********** Data Not Found! pos - ('BX', '20170430')**********
# ('ZE', '20170518')
# ********** Data Not Found! pos - ('ZE', '20170518')**********
# ('BX', '20170501')
# ('BX', '20170517')
# ('LJ', '20170510')
#   airline  dpt_date    flt   dpt   arr  fare1 fare2  fare3 seat
# 0      ZE  20170524  ZE201  0615  0725  38100     0  71700    9
# 1      ZE  20170524  ZE203  0650  0755  62100     0  71700    9
# 2      ZE  20170524  ZE215  1255  1405  67100     0  71700    9
# 3      ZE  20170524  ZE217  1435  1545  38100     0  71700    9
# 4      ZE  20170524  ZE219  1540  1650  32100     0  71700    9

# %%
## 국제선 기간 데이터 읽어오기
dpt, arr, airlines = 'GMP','CJU',['7C','TW','ZE','LJ','BX']
start, end = 31,45
raw_data_dict = crawling_WebTour_from_to(airlines,dpt,arr,start=start,end=end)

df = make_raw_data_dict_to_df(dpt,arr,start,end,raw_data_dict)
df.head()
# Out:
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170526 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170526 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170526 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170526 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170526 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170526 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170526 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170526 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170526 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170526 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170527 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170527 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170527 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170527 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170527 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170527 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170527 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170527 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170527 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170527 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170528 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170528 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170528 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170528 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170528 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170528 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170528 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170528 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170528 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170528 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170529 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170529 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170529 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170529 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170529 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170529 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170529 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170529 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170529 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170529 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170530 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170530 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170530 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170530 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170530 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170530 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170530 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170530 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170530 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170530 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170531 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170531 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170531 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170531 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170531 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170531 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170531 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170531 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170531 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170531 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170601 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170601 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170601 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170601 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170601 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170601 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170601 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170601 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170601 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170601 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170602 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170602 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170602 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170602 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170602 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170602 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170602 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170602 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170602 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170602 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170603 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170603 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170603 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170603 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170603 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170603 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170603 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170603 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170603 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170603 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170604 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170604 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170604 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170604 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170604 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170604 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170604 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170604 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170604 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170604 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170605 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170605 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170605 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170605 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170605 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170605 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170605 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170605 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170605 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170605 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170606 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170606 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170606 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170606 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170606 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170606 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170606 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170606 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170606 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170606 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170607 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170607 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170607 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170607 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170607 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170607 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170607 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170607 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170607 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170607 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170608 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170608 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170608 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170608 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170608 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170608 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170608 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170608 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170608 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170608 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling Total Result :  70
# ********** Data Not Found! pos - ('ZE', '20170601')**********
#   airline  dpt_date    flt   dpt   arr fare1 fare2   fare3 seat
# 0      7C  20170605  7C101  0630  0740     0     0  103900    9
# 1      7C  20170605  7C103  0700  0810     0     0  103900    9
# 2      7C  20170605  7C105  0750  0900     0     0  103900    9
# 3      7C  20170605  7C107  0900  1010     0     0  103900    9
# 4      7C  20170605  7C113  1120  1230     0     0  103900    9

# %%
## 국제선 기간 데이터 읽어오기
dpt, arr, airlines = 'GMP','CJU',['7C','TW','ZE','LJ','BX']
start, end = 45,90
raw_data_dict = crawling_WebTour_from_to(airlines,dpt,arr,start=start,end=end)

df = make_raw_data_dict_to_df(dpt,arr,start,end,raw_data_dict)
df.head()
# Out:
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170609 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170609 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170609 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170609 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170609 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170609 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170609 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170609 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170609 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170609 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170610 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170610 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170610 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170610 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170610 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170610 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170610 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170610 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170610 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170610 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170611 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170611 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170611 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170611 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170611 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170611 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170611 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170611 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170611 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170611 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170612 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170612 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170612 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170612 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170612 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170612 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170612 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170612 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170612 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170612 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170613 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170613 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170613 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170613 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170613 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170613 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170613 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170613 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170613 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170613 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170614 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170614 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170614 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170614 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170614 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170614 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170614 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170614 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170614 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170614 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170615 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170615 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170615 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170615 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170615 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170615 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170615 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170615 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170615 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170615 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170616 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170616 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170616 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170616 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170616 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170616 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170616 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170616 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170616 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170616 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170617 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170617 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170617 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170617 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170617 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170617 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170617 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170617 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170617 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170617 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170618 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170618 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170618 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170618 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170618 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170618 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170618 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170618 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170618 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170618 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170619 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170619 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170619 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170619 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170619 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170619 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170619 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170619 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170619 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170619 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170620 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170620 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170620 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170620 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170620 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170620 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170620 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170620 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170620 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170620 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170621 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170621 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170621 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170621 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170621 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170621 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170621 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170621 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170621 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170621 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170622 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170622 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170622 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170622 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170622 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170622 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170622 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170622 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170622 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170622 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170623 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170623 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170623 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170623 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170623 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170623 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170623 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170623 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170623 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170623 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170624 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170624 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170624 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170624 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170624 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170624 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170624 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170624 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170624 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170624 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170625 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170625 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170625 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170625 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170625 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170625 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170625 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170625 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170625 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170625 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170626 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170626 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170626 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170626 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170626 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170626 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170626 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170626 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170626 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170626 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170627 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170627 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170627 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170627 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170627 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170627 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170627 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170627 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170627 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170627 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170628 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170628 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170628 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170628 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170628 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170628 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170628 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170628 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170628 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170628 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170629 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170629 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170629 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170629 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170629 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170629 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170629 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170629 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170629 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170629 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170630 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170630 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170630 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170630 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170630 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170630 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170630 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170630 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170630 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170630 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170701 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170701 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170701 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170701 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170701 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170701 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170701 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170701 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170701 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170701 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170702 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170702 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170702 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170702 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170702 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170702 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170702 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170702 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170702 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170702 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170703 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170703 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# ...
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170716 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170716 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170716 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170716 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170716 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170716 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170717 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170717 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170717 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170717 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170717 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170717 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170717 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170717 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170717 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170717 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170718 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170718 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170718 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170718 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170718 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170718 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170718 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170718 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170718 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170718 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170719 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170719 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170719 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170719 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170719 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170719 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170719 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170719 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170719 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170719 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170720 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170720 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170720 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170720 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170720 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170720 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170720 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170720 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170720 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170720 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170721 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170721 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170721 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170721 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170721 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170721 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170721 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170721 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170721 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170721 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170722 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170722 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170722 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170722 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170722 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170722 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170722 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170722 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170722 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170722 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:7C , whereSDate:20170723 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170723 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:TW , whereSDate:20170723 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170723 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:ZE , whereSDate:20170723 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170723 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:LJ , whereSDate:20170723 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170723 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling WebTour domastic schedule site
# Start Simple crawling :  http://www.webtour.com/DA/da__ajx.asp
# >> Parameters
# whereDirection: , whereItinerary:oneway , whereICnt:0 , cmd:Ajx_DAir_SetAvaliList_ALL , whereTarget:daRTBx , whereCarCode:BX , whereSDate:20170723 , whereArrCity:CJU , whereDepCity:GMP , whereEDate:20170723 , whereCCnt:0 , whereACnt:1 , whereSeatClass:All ,
# End Simple crawling
# Crawling Total Result :  225
# ********** Data Not Found! pos - ('ZE', '20170619')**********
# ********** Data Not Found! pos - ('ZE', '20170708')**********
# ********** Data Not Found! pos - ('ZE', '20170624')**********
# ********** Data Not Found! pos - ('ZE', '20170718')**********
# ********** Data Not Found! pos - ('ZE', '20170626')**********
# ********** Data Not Found! pos - ('ZE', '20170627')**********
# ********** Data Not Found! pos - ('ZE', '20170614')**********
#   airline  dpt_date     flt   dpt   arr  fare1 fare2  fare3 seat
# 0      LJ  20170628  LJ0301  0615  0720  37700     0  71800    9
# 1      LJ  20170628  LJ0303  0625  0730  37700     0  71800    9
# 2      LJ  20170628  LJ0305  0800  0910  58700     0  71800    9
# 3      LJ  20170628  LJ0307  0845  0955  62000     0  71800    9
# 4      LJ  20170628  LJ0311  1025  1135  58700     0  71800    9

# %%
datetime.today().strftime('%Y%m%d%H%M')
# Out:
# '201704251124'
