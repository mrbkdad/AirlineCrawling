# %% [markdown]
# ## 김포 제주(인천 나리타) 노선 가격 정보 읽어오기 1 - 1
# - 대상 사이트 : 제주항공 웹사이트, 인터파크 국내선 실시간 예매사이트

# %% [markdown]
# ### 제주항공 사이트 웹 크롤링
#     - 제주항공 항공권예매 페이지를 이용한 크롤링
#     - 세션을 생성하여 세션을 이용해 json API 페이지 호출 하여 정보 획득
#     - 필요 데이터 추출 하여 Pandas 의 DataFrame 형태로 생성
#     - 생성된 데이터 엑셀 파일로 저장

# %%
from IPython.display import display
import requests
import pandas as pd
import numpy as np
from pandas import DataFrame
from bs4 import BeautifulSoup
import time
from datetime import datetime
from datetime import timedelta
from common.crawling_util import session_crawling

def crawling_7C_data(dpt,arr,dpt_date):
    ##출발지, 도착지, 출발일을 기준으로 국내선(국제선) 편도 가격 읽어오기
    print('Start crawling info from 7C......')
    url = "https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do"
    head = {
        'Referer':'http://www.jejuair.net/jejuair/main.jsp',
    }
    print('>> make session info')
    sess = requests.Session()
    req = sess.get(url,headers=head)
    ## 세션 정보 확인시 필요
    #print(sess.cookies,sess.cookies.get_dict())
    time.sleep(1) ## 처리중 지연 현상 처리를 위해 1초간 sleep
    
    url = 'https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do'
    head = {
        'Referer':'https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do',
    }
    param ={
        'AdultPaxCnt':'1',
        'ChildPaxCnt':'0',
        'InfantPaxCnt':'0',
        'RouteType':'I',  ## 국내선 D, 국제선 I
        'SystemType':'IBE',
        'Language':'KR',
        'DepStn':dpt,
        'ArrStn':arr,
        'SegType':'DEP',
        'TripType':'OW',
        'DepDate':dpt_date,
        'Index':'1' #국제선용
    }

    print('>> crawl one way fare info : Departure - {}, Arrival - {}, Date - {}, Type - {}'.format(dpt,arr,dpt_date,dom_int))
    req = sess.post(url,param,headers=head)
    time.sleep(1) ## 처리중 지연 현상 처리를 위해 1초간 sleep
    print('......End crawling info from 7C')
    return req.json()

data_fields = ['fltNo','depTime','arrTime','specialEquivFare','specialEquivFareBasis',
               'discountEquivFare','discountEquivFareBasis','fare','fareBasis']
data_heads = ['flt','dpt','arr','fare1','type1','fare2','type2','fare3','type3']
## raw 데이터로 부터 DataFrame 생성
def raw_to_df(raw_data,dom_int='D'):
    if dom_int == 'D':
        return  d_raw_to_df(raw_data)
    else:
        return i_raw_to_df(raw_data)

## 국내선용
d_data_fields = ['depDate','fltNo','depTime','arrTime','specialEquivFare','discountEquivFare',
                 'fare','normalRBD','fareBasis','normalSeatCount']
d_data_heads = ['date','flt','dpt','arr','fare1','fare2','fare3','rbd','fare_basis','seat']
def d_raw_to_df(raw_data):
    ## 읽어온 데이터의 json['Result']['code'] 값이 0000 이 아닌 경우 오류
    if raw_data['Result']['code'] != '0000':
        return None

    raw_fares = raw_data['Result']['data']
    fare_data = []
    for fare in raw_fares:
        line_info = []
        for f in d_data_fields:
            line_info.append(fare[f])
        fare_data.append(line_info)
    return DataFrame(fare_data,columns=d_data_heads)
## 국제선용
i_data_fields = ['depDate','fltNo','depTime','arrTime','specialEquivFare','discountEquivFare',
                 'normalEquivFare','normalRBD','normalEquivFareBasis','normalSeatCount']
i_data_heads = ['date','flt','dpt','arr','fare1','fare2','fare3','rbd','fare_basis','seat']
def i_raw_to_df(raw_data):
    ## 읽어온 데이터의 json['Result']['code'] 값이 0000 이 아닌 경우 오류
    if raw_data['Result']['code'] != '0000':
        return None
    
    raw_fares = raw_data['Result']['data']['availData']
    fare_data = []
    for fare in raw_fares:
        line_info = []
        for f in i_data_fields:
            line_info.append(fare[f])
        fare_data.append(line_info)
    return DataFrame(fare_data,columns=i_data_heads)

## 유류할증료, 공항세 읽어오기
## 노선별 날짜별 fare base 에 상관없이 똑같다는 가정
## raw 데이터로 부터 DataFrame 생성
def crawling_7C_tax(dpt,arr,flt,dpt_date,dpt_time,arr_time,fare,rbd,basis,dom_int='D'):
    url = 'https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do'
    head = {
        'Referer':'https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do',
    }
    param ={
        'DepDate':dpt_date+dpt_time,
        'ArrDate':dpt_date+arr_time,
        'DepStn':dpt,
        'ArrStn':arr,
        'RBD':rbd,
        'FareBasis':basis,
        'EquivFare':fare,
        'FltNo':flt,
        'FareTypeNo':'3',## Normal Fare 기준
        'TripType':'OW',
        'RouteType':dom_int, ## 국내선 국제선 구분
        #'SystemType':'IBE'
        #'depDesc':'서울(김포)',
        #'arrDesc':'제주',
        #'ReqType':'Price',
        #'AdultPaxCnt':'1',
        #'ChildPaxCnt':'0',
        #'InfantPaxCnt':'0',
        #'Language':'KR',
    }
    print('crawling tax - param\n',param)
    raw_tax = requests.post(url,param,headers=head).json()
    #return raw_tax
    return (raw_tax['Result']['data'][0]['farePriceTaxDataBeans'][0]['taxAmount'],
            raw_tax['Result']['data'][0]['farePriceTaxDataBeans'][1]['taxAmount'])



## 하루 기준 가격정보, 텍스정보, 최소값, 최대값, 평균 DataFrame 생성
def read_7C_1day_fare(dpt,arr,dpt_date,dom_int):
    ## 데이터 읽어오기
    raw_data = crawling_7C_data(dpt,arr,dpt_date,dom_int)
    df=raw_to_df(raw_data,dom_int)
    if df is None or len(df) == 0: ## 읽는 도중 에러가 나거나 익셉션 발생으로 문제가 있을 경우 처리
        print('********** No Data Type 1 **********')
        return None
    ## tax 읽어오기
    df_tax = df[df['seat'] != '0']
    if len(df_tax) == 0: ## 읽어온 값의 좌석이 아무것도 없을 경우
        print('********** No Data Type 2 **********')
        df['tax1'],df['tax2'] = 0,0
    else:    
        flt,dpt_time,arr_time,fare,rbd,basis=df_tax.values[0,[1,2,3,6,7,8]]
        df['tax1'],df['tax2'] = crawling_7C_tax(dpt,arr,flt,dpt_date,dpt_time,arr_time,fare,rbd,basis,dom_int)
    ## 최소값 최대값 평균 계산
    fare_arr = df[df['seat'] != '0'][['fare1','fare2','fare3']].values ## fare 만 구해오기
    fare_arr = fare_arr.reshape(1,-1) # shape 1차원으로 변경
    fare_arr = np.unique(fare_arr)
    if '' in fare_arr or '0' in fare_arr:
        fare_arr = fare_arr[1:] # 0 값 제거
    fare_arr = fare_arr.astype('int') # 중복값 제거, 수치형으로 변경
    #if 0 in fare_arr:
    #    fare_arr = fare_arr[1:] # 0 값 제거
    ## 요약정보 추가
    df.ix[len(df)] = [dpt_date,'min','max','mean',str(fare_arr.min()),str(fare_arr.max()),str(fare_arr.mean()),'','','','','']
    return df

## 정해진 기간의 데이터 읽어오기, 기본 30일
def read_7C_date_range_fare(dpt,arr,dom_int,n=30):
    # 기본 30일간 데이터 읽어서 파일로 저장
    date_range = [ (datetime.today()+timedelta(1)*i).strftime('%Y%m%d') for i in range(n)]
    fare_list = []
    for d in date_range:
        try:
            fare_df = read_7C_1day_fare(dpt,arr,d,dom_int)
            if fare_df is not None:
                fare_list.append(fare_df)
        except Exception as e:
            print('****** Error occured : ',e)
    result = pd.concat(fare_list,ignore_index=True)
    print('++++++++++Total : ', len(result))
    ## 파일 저장
    result.to_excel('{}/{}_{}_{}_{}_{}_{}.xls'.format('excel','7C',dpt,arr,dpt_date,n,datetime.today().strftime('%Y%m%d%H%m')))
    return result

# %%
## 하루치 데이터 읽어오기
dpt, arr, dpt_date, dom_int = 'GMP','CJU','20170514','D'
#dpt, arr, dpt_date, dom_int = 'ICN','NRT','2017-05-01','I'

crawling_7C_data(dpt,arr,dpt_date,dom_int)
#read_7C_1day_fare(dpt,arr,dpt_date,dom_int)
# Out:
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170514, Type - D
# ......End crawling info from 7C
# {'Result': {'code': '0000',
#   'data': [{'RBD': 'N',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '0730',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '0625',
#     'discountEquivFare': '51900',
#     'discountEquivFareBasis': 'NY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'N',
#     'discountSeatCount': '9',
#     'equivFare': '51900',
#     'equivFareBasis': 'NY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '151 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'N',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '0740',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '0630',
#     'discountEquivFare': '51900',
#     'discountEquivFareBasis': 'NY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'N',
#     'discountSeatCount': '9',
#     'equivFare': '51900',
#     'equivFareBasis': 'NY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '101 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'R',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '0810',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '0700',
#     'discountEquivFare': '68900',
#     'discountEquivFareBasis': 'RY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'R',
#     'discountSeatCount': '9',
#     'equivFare': '68900',
#     'equivFareBasis': 'RY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '103 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'R',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '0900',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '0750',
#     'discountEquivFare': '68900',
#     'discountEquivFareBasis': 'RY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'R',
#     'discountSeatCount': '9',
#     'equivFare': '68900',
#     'equivFareBasis': 'RY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '105 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'R',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '1010',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '0900',
#     'discountEquivFare': '68900',
#     'discountEquivFareBasis': 'RY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'R',
#     'discountSeatCount': '9',
#     'equivFare': '68900',
#     'equivFareBasis': 'RY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '107 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'R',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '1055',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '0945',
#     'discountEquivFare': '68900',
#     'discountEquivFareBasis': 'RY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'R',
#     'discountSeatCount': '9',
#     'equivFare': '68900',
#     'equivFareBasis': 'RY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '141 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'S',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '1115',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '1005',
#     'discountEquivFare': '75900',
#     'discountEquivFareBasis': 'SY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'S',
#     'discountSeatCount': '9',
#     'equivFare': '75900',
#     'equivFareBasis': 'SY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '111 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'O',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '1335',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '1225',
#     'discountEquivFare': '56900',
#     'discountEquivFareBasis': 'OY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'O',
#     'discountSeatCount': '9',
#     'equivFare': '56900',
#     'equivFareBasis': 'OY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '115 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'O',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '1350',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '1240',
#     'discountEquivFare': '56900',
#     'discountEquivFareBasis': 'OY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'O',
#     'discountSeatCount': '9',
#     'equivFare': '56900',
#     'equivFareBasis': 'OY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '117 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'N',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '1425',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '1315',
#     'discountEquivFare': '51900',
#     'discountEquivFareBasis': 'NY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'N',
#     'discountSeatCount': '9',
#     'equivFare': '51900',
#     'equivFareBasis': 'NY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '143 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'M',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '1505',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '1350',
#     'discountEquivFare': '46900',
#     'discountEquivFareBasis': 'MY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'M',
#     'discountSeatCount': '9',
#     'equivFare': '46900',
#     'equivFareBasis': 'MY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '119 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'M',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '1550',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '1440',
#     'discountEquivFare': '46900',
#     'discountEquivFareBasis': 'MY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'M',
#     'discountSeatCount': '9',
#     'equivFare': '46900',
#     'equivFareBasis': 'MY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '121 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'L',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '1640',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '1525',
#     'discountEquivFare': '41900',
#     'discountEquivFareBasis': 'LY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'L',
#     'discountSeatCount': '9',
#     'equivFare': '41900',
#     'equivFareBasis': 'LY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '155 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'L',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '1655',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '1545',
#     'discountEquivFare': '41900',
#     'discountEquivFareBasis': 'LY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'L',
#     'discountSeatCount': '9',
#     'equivFare': '41900',
#     'equivFareBasis': 'LY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '123 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'L',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '1715',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '1605',
#     'discountEquivFare': '41900',
#     'discountEquivFareBasis': 'LY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'L',
#     'discountSeatCount': '9',
#     'equivFare': '41900',
#     'equivFareBasis': 'LY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '125 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'L',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '1755',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '1645',
#     'discountEquivFare': '41900',
#     'discountEquivFareBasis': 'LY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'L',
#     'discountSeatCount': '9',
#     'equivFare': '41900',
#     'equivFareBasis': 'LY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '145 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'M',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '1925',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '1815',
#     'discountEquivFare': '46900',
#     'discountEquivFareBasis': 'MY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'M',
#     'discountSeatCount': '9',
#     'equivFare': '46900',
#     'equivFareBasis': 'MY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '127 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'M',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '2015',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '1905',
#     'discountEquivFare': '46900',
#     'discountEquivFareBasis': 'MY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'M',
#     'discountSeatCount': '9',
#     'equivFare': '46900',
#     'equivFareBasis': 'MY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '129 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'M',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '2045',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '1935',
#     'discountEquivFare': '46900',
#     'discountEquivFareBasis': 'MY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'M',
#     'discountSeatCount': '9',
#     'equivFare': '46900',
#     'equivFareBasis': 'MY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '133 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''},
#    {'RBD': 'M',
#     'YClassStatusCode': '',
#     'acType': '737',
#     'afterDepDate': '',
#     'afterMinFare': '0',
#     'arrDate': '20170514',
#     'arrStn': 'CJU',
#     'arrStnDesc': '제주(CJU)',
#     'arrTime': '2135',
#     'beforeDepDate': '',
#     'beforeMinFare': '0',
#     'carrier': '7C',
#     'connectAvailData': {'acType': '',
#      'arrDate': '',
#      'arrStn': '',
#      'arrStnDesc': '',
#      'arrTime': '',
#      'carrier': '',
#      'currency': '',
#      'depDate': '',
#      'depStn': '',
#      'depStnDesc': '',
#      'depTime': '',
#      'discountEquivFare': '',
#      'discountEquivFareBasis': '',
#      'discountEquivFareName': '',
#      'discountRBD': '',
#      'fltNo': '',
#      'fltType': '',
#      'normalEquivFare': '',
#      'normalEquivFareBasis': '',
#      'normalEquivFareName': '',
#      'normalRBD': '',
#      'specialEquivFare': '',
#      'specialEquivFareBasis': '',
#      'specialEquivFareName': '',
#      'specialRBD': ''},
#     'connectNo': '',
#     'currency': 'KRW',
#     'depDate': '20170514',
#     'depStn': 'GMP',
#     'depStnDesc': '서울(김포)(GMP)',
#     'depTime': '2025',
#     'discountEquivFare': '46900',
#     'discountEquivFareBasis': 'MY',
#     'discountEquivFareName': '할인운임',
#     'discountEquivTotalFare': '',
#     'discountFareRuleInfoDatas': [],
#     'discountFareRuleNo': '',
#     'discountFee': '',
#     'discountRBD': 'M',
#     'discountSeatCount': '9',
#     'equivFare': '46900',
#     'equivFareBasis': 'MY',
#     'fare': '80000',
#     'fareBasis': 'YW',
#     'fareRuleNo': '',
#     'fltNo': '147 ',
#     'fltType': '',
#     'fuelCharge': '0',
#     'groupFareDatas': [],
#     'jjimFlag': '',
#     'minFare': '0',
#     'nonFlt': '',
#     'normalEquivFare': '80000',
#     'normalEquivFareBasis': '',
#     'normalEquivFareName': '정상운임',
#     'normalEquivTotalFare': '',
#     'normalFareRuleInfoDatas': [],
#     'normalFareRuleNo': '',
#     'normalFee': '',
#     'normalRBD': 'Y',
#     'normalSeatCount': '9',
#     'pointFareInfo': {'discountEquivFarePoint': '',
#      'minFarePoint': '',
#      'normalEquivFarePoint': '',
#      'pntClassFareBasis': '',
#      'pntClassRBD': '',
#      'pntClassSeatCount': '',
#      'specialEquivFarePoint': ''},
#     'pointUseRate': '',
#     'seatAvailDataBeans': [],
#     'seatCount': '9',
#     'seatDesc': '',
#     'specialEquivFare': '0',
#     'specialEquivFareBasis': '',
#     'specialEquivFareName': '',
#     'specialEquivTotalFare': '',
#     'specialFareRuleInfoDatas': [],
#     'specialFareRuleNo': '',
#     'specialFee': '',
#     'specialRBD': '',
#     'specialSeatCount': '0',
#     'tax': '0',
#     'taxDataIndex': ''}],
#   'message': ''}}

# %%
## 정해진 기간의 데이터 읽어오기
dpt, arr,dom_int = 'GMP','CJU','D'
ndate = 30 ## 읽어올 데이터 기간
read_7C_date_range_fare(dpt,arr,dom_int,ndate)
# Out:
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170420, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YX', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '65600', 'DepDate': '201704201815', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201704201925', 'ArrStn': 'CJU', 'FltNo': '127 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170421, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YP', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '97700', 'DepDate': '201704211315', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201704211425', 'ArrStn': 'CJU', 'FltNo': '143 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170422, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YP', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '97700', 'DepDate': '201704221440', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201704221550', 'ArrStn': 'CJU', 'FltNo': '121 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170423, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YW', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '80000', 'DepDate': '201704230625', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201704230730', 'ArrStn': 'CJU', 'FltNo': '151 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170424, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YX', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '65600', 'DepDate': '201704240625', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201704240730', 'ArrStn': 'CJU', 'FltNo': '151 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170425, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YX', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '65600', 'DepDate': '201704250625', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201704250730', 'ArrStn': 'CJU', 'FltNo': '151 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170426, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YX', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '65600', 'DepDate': '201704260625', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201704260730', 'ArrStn': 'CJU', 'FltNo': '151 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170427, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YX', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '65600', 'DepDate': '201704270625', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201704270730', 'ArrStn': 'CJU', 'FltNo': '151 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170428, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YP', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '97700', 'DepDate': '201704281315', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201704281425', 'ArrStn': 'CJU', 'FltNo': '143 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170429, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YH', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '97700', 'DepDate': '201704290620', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201704290730', 'ArrStn': 'CJU', 'FltNo': '161 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170430, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YH', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '97700', 'DepDate': '201704301525', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201704301640', 'ArrStn': 'CJU', 'FltNo': '155 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170501, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YH', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '97700', 'DepDate': '201705010620', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201705010730', 'ArrStn': 'CJU', 'FltNo': '161 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170502, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YH', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '97700', 'DepDate': '201705020620', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201705020730', 'ArrStn': 'CJU', 'FltNo': '161 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170503, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YH', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '97700', 'DepDate': '201705032025', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201705032135', 'ArrStn': 'CJU', 'FltNo': '147 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170504, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YH', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '97700', 'DepDate': '201705040630', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201705040740', 'ArrStn': 'CJU', 'FltNo': '101 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170505, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YH', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '97700', 'DepDate': '201705051315', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201705051425', 'ArrStn': 'CJU', 'FltNo': '143 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170506, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YH', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '97700', 'DepDate': '201705060625', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201705060730', 'ArrStn': 'CJU', 'FltNo': '151 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170507, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YH', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '97700', 'DepDate': '201705070620', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201705070730', 'ArrStn': 'CJU', 'FltNo': '161 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170508, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YH', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare': '97700', 'DepDate': '201705080620', 'FareTypeNo': '3', 'DepStn': 'GMP', 'ArrDate': '201705080730', 'ArrStn': 'CJU', 'FltNo': '161 ', 'RouteType': 'D'}
# Start crawling info from 7C......
# >> make session info
# >> crawl one way fare info : Departure - GMP, Arrival - CJU, Date - 20170509, Type - D
# ......End crawling info from 7C
# crawling tax - param
#  {'FareBasis': 'YX', 'RBD': 'Y', 'TripType': 'OW', 'EquivFare':
# 116  20170514  1102  0830  1050          110000         360000   Y     YOW2KR
# 117  20170514  1106  1035  1255          130000         360000   Y     YOW2KR
# 118  20170514  1104  1505  1730          150000         360000   Y     YOW2KR
# 119  20170514   min   max  mean  110000  360000       187500.0
# 120  20170515  1162  0700  0950           85000         360000   Y     YOW2KR
# 121  20170515  1102  0830  1050          110000         360000   Y     YOW2KR
# 122  20170515  1106  1035  1255          130000         360000   Y     YOW2KR
# 123  20170515  1104  1505  1730          150000         360000   Y     YOW2KR
# 124  20170515   min   max  mean   85000  360000       167000.0
# 125  20170516  1162  0700  0950           75000         360000   Y     YOW2KR
# 126  20170516  1102  0830  1050           75000         360000   Y     YOW2KR
# 127  20170516  1106  1035  1255           75000         360000   Y     YOW2KR
# 128  20170516  1104  1505  1730           75000         360000   Y     YOW2KR
# 129  20170516   min   max  mean   75000  360000       217500.0
# 130  20170517  1162  0700  0950           75000         360000   Y     YOW2KR
# 131  20170517  1102  0830  1050           75000         360000   Y     YOW2KR
# 132  20170517  1106  1035  1255          120000         360000   Y     YOW2KR
# 133  20170517  1104  1505  1730           75000         360000   Y     YOW2KR
# 134  20170517   min   max  mean   75000  360000       185000.0
# 135  20170518  1162  0700  0950           75000         360000   Y     YOW2KR
# 136  20170518  1102  0830  1050          130000         360000   Y     YOW2KR
# 137  20170518  1106  1035  1255          130000         360000   Y     YOW2KR
# 138  20170518  1104  1505  1730          120000         360000   Y     YOW2KR
# 139  20170518   min   max  mean   75000  360000       171250.0
# 140  20170519  1162  0700  0950           85000         360000   Y     YOW2KR
# 141  20170519  1102  0830  1050          120000         360000   Y     YOW2KR
# 142  20170519  1106  1035  1255          160000         360000   Y     YOW2KR
# 143  20170519  1104  1505  1730          120000         360000   Y     YOW2KR
# 144  20170519   min   max  mean   85000  360000       181250.0
#
#     seat  tax1   tax2
# 0      6  1200  28000
# 1      7  1200  28000
# 2      4  1200  28000
# 3      9  1200  28000
# 4
# 5      9  1200  28000
# 6      9  1200  28000
# 7      9  1200  28000
# 8      9  1200  28000
# 9
# 10     9  1200  28000
# 11     9  1200  28000
# 12     3  1200  28000
# 13     9  1200  28000
# 14
# 15     9  1200  28000
# 16     9  1200  28000
# 17     9  1200  28000
# 18     9  1200  28000
# 19
# 20     9  1200  28000
# 21     9  1200  28000
# 22     9  1200  28000
# 23     9  1200  28000
# 24
# 25     9  1200  28000
# 26     9  1200  28000
# 27     9  1200  28000
# 28     9  1200  28000
# 29
# ..   ...   ...    ...
# 115    9  1200  28000
# 116    9  1200  28000
# 117    9  1200  28000
# 118    9  1200  28000
# 119
# 120    9  1200  28000
# 121    9  1200  28000
# 122    9  1200  28000
# 123    9  1200  28000
# 124
# 125    9  1200  28000
# 126    9  1200  28000
# 127    9  1200  28000
# 128    9  1200  28000
# 129
# 130    9  1200  28000
# 131    9  1200  28000
# 132    9  1200  28000
# 133    9  1200  28000
# 134
# 135    9  1200  28000
# 136    9  1200  28000
# 137    9  1200  28000
# 138    9  1200  28000
# 139
# 140    9  1200  28000
# 141    9  1200  28000
# 142    9  1200  28000
# 143    9  1200  28000
# 144
#
# [145 rows x 12 columns]
