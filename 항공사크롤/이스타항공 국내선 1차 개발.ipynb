# %% [markdown]
# ## 김포 제주 노선 가격 정보 읽어오기
# - 대상 사이트 : 이스타항공 웹사이트

# %% [markdown]
# ### 이스타항공 사이트 웹 크롤링
#     - 이스타항공 항공권예매 페이지를 이용한 크롤링
#     - 세션을 생성하여 세션을 이용해 json API 페이지 호출 하여 정보 획득
#     - 파라미터는 JSON 형식으로 별도의 처리용 함수 가 필요
#     - 필요 데이터 추출 하여 Pandas 의 DataFrame 형태로 생성
#     - 생성된 데이터 엑셀 파일로 저장
#
# ### 우선 사이트 스크래핑용 함수만 먼저 생성

# %%
from IPython.display import display
import requests
import pandas as pd
import numpy as np
from pandas import DataFrame
from bs4 import BeautifulSoup
import time
from datetime import datetime
from datetime import timedelta
from common.crawling_util import jsonpayload_crawling
from common.parsing_util import parsing_json_data_to_dict

## Payload 구조
def get_ZE_payload(flightSearch):
    payLoad={
        "id": 2, "method": "DataService.service",
        "params": [{
            "javaClass": "com.jein.framework.connectivity.parameter.RequestParameter",
            "requestUniqueCode": "PGWBA00002", "requestExecuteType": "BIZ",
            "DBTransaction": False, "sourceName": None, "sourceExtension": None,
            "functionName": "DTWBA00022", "panelId": None, "methodType": None,
            "inParameters": {
                "javaClass": "java.util.List",
                "list": [{
                    "javaClass": "com.jein.framework.connectivity.parameter.InParameter",
                    "paramName": "flightSearch", "ioType": "IN", "structureType": "FIELD",
                    "data": {
                        "javaClass": "java.util.List",
                        "list": [{
                            "map": {
                                "flightSearch": flightSearch
                            },
                            "javaClass": "java.util.Map"}]
                        }
                }]
            },
            "filterParameter": {"javaClass": "java.util.Map", "map": {}}
        }]
    }
    return payLoad

def crawling_ZE_data(dpt,arr,dpt_date):
    ##출발지, 도착지, 출발일을 기준으로 국내선(국제선) 편도 가격 읽어오기
    print('Crawling eastarjet homepage schedule site')
    session_url = "https://www.eastarjet.com/newstar/PGWBA00001"
    session_head = {
        'Referer':'https://www.eastarjet.com/newstar/PGWBA00001',
        'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36'
    }
    sess = requests.Session()
    sess.get(session_url,headers=session_head)
    
    url = 'https://www.eastarjet.com/json/dataService'
    head = {
        'Referer':'https://www.eastarjet.com/newstar/PGWBA00002',
        'User-Agent':'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36'
    }

    flightSearch='{"viewType":"","fly_type":"2","person1":"1","person2":"0","person3":"0",\
    "residentCountry":"KR","currency":"","promotion_cd":"",\
    "flySection":[{"departure_cd":"{departure_cd}","arrival_cd":"{arrival_cd}","departure_date_cd":"{departure_date_cd}"}]}'
    #req = requests.post(url,json=payload,headers=head)
    payload = get_ZE_payload(flightSearch.replace('{departure_cd}',dpt).replace('{arrival_cd}',arr).replace('{departure_date_cd}',dpt_date))
    return jsonpayload_crawling(url, payload, sess=sess, head=head, method='post', json=True)

## 국내선용 파싱 정보
loop_field = "['Result']['data']"
parse_info = {
    'date':"['Result']['data'][{}]['depDate']",#i
    'flt':"['Result']['data'][{}]['fltNo']",#i
    'dpt':"['Result']['data'][{}]['depTime']",#i
    'arr':"['Result']['data'][{}]['arrTime']",#i
    'fare1':"['Result']['data'][{}]['specialEquivFare']",#i
    'fare2':"['Result']['data'][{}]['discountEquivFare']",#i
    'fare3':"['Result']['data'][{}]['fare']",#i
    'rbd':"['Result']['data'][{}]['normalRBD']",#i
    'fare_basis':"['Result']['data'][{}]['fareBasis']",#i
    'seat':"['Result']['data'][{}]['normalSeatCount']",#i
}
data_heads = ['date','flt','dpt','arr','fare1','fare2','fare3','rbd','fare_basis','seat']
## raw 데이터로 부터 DataFrame 생성
def raw_to_df(raw_data):
    ## 읽어온 데이터의 json['Result']['code'] 값이 0000 이 아닌 경우 오류
    if raw_data['Result']['code'] != '0000':
        return None

    return pd.DataFrame(parsing_json_data_to_dict(raw_data, loop_field, parse_info))

## 유류할증료, 공항세 읽어오기
## 노선별 날짜별 fare base 에 상관없이 똑같다는 가정
## raw 데이터로 부터 DataFrame 생성
def crawling_7C_tax(dpt,arr,flt,dpt_date,dpt_time,arr_time,fare,rbd,basis):
    url = 'https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do'
    head = {
        'Referer':'https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do',
    }
    param ={
        'DepDate':dpt_date+dpt_time,              'ArrDate':dpt_date+arr_time,
        'DepStn':dpt,        'ArrStn':arr,        'RBD':rbd,
        'FareBasis':basis,   'EquivFare':fare,    'FltNo':flt,
        'FareTypeNo':'3',## Normal Fare 기준
        'TripType':'OW',     'RouteType':dom_int, ## 국내선 국제선 구분
        #'SystemType':'IBE'        #'depDesc':'서울(김포)',        #'arrDesc':'제주',
        #'ReqType':'Price',        #'AdultPaxCnt':'1',             #'ChildPaxCnt':'0',
        #'InfantPaxCnt':'0',       #'Language':'KR',
    }
    raw_tax = simple_crawling(url, param, head=head, method='post', json=True)
    return (raw_tax['Result']['data'][0]['farePriceTaxDataBeans'][0]['taxAmount'],
            raw_tax['Result']['data'][0]['farePriceTaxDataBeans'][1]['taxAmount'])



## 하루 기준 가격정보, 텍스정보, 최소값, 최대값, 평균 DataFrame 생성
def read_7C_1day_fare(dpt,arr,dpt_date):
    ## 데이터 읽어오기
    raw_data = crawling_7C_data(dpt,arr,dpt_date)
    df=raw_to_df(raw_data)
    if df is None or len(df) == 0: ## 읽는 도중 에러가 나거나 익셉션 발생으로 문제가 있을 경우 처리
        print('********** No Data Type 1 **********')
        return None
    ## tax 읽어오기
    df_tax = df[df['seat'] != '0']
    if len(df_tax) == 0: ## 읽어온 값의 좌석이 아무것도 없을 경우
        print('********** No Data Type 2 **********')
        df['tax1'],df['tax2'] = 0,0
    else:    
        flt,dpt_time,arr_time,fare,rbd,basis=df_tax[data_heads].values[0,[1,2,3,6,7,8]]
        df['tax1'],df['tax2'] = crawling_7C_tax(dpt,arr,flt,dpt_date,dpt_time,arr_time,fare,rbd,basis)
    ## 최소값 최대값 평균 계산
    fare_arr = df[df['seat'] != '0'][['fare1','fare2','fare3']].values ## fare 만 구해오기
    fare_arr = fare_arr.reshape(1,-1) # shape 1차원으로 변경
    fare_arr = np.unique(fare_arr)
    if '' in fare_arr or '0' in fare_arr:
        fare_arr = fare_arr[1:] # 0 값 제거
    fare_arr = fare_arr.astype('int') # 중복값 제거, 수치형으로 변경
    #if 0 in fare_arr:
    #    fare_arr = fare_arr[1:] # 0 값 제거
    ## 요약정보 추가
    df.ix[len(df)] = [dpt_date,'min','max','mean',str(fare_arr.min()),str(fare_arr.max()),str(fare_arr.mean()),'','','','','']
    return df

## 정해진 기간의 데이터 읽어오기, 기본 30일
def read_7C_date_range_fare(dpt,arr,start=0,end=31):
    # 기본 30일간 데이터 읽어서 파일로 저장
    date_range = [ (datetime.today()+timedelta(1)*i).strftime('%Y%m%d') for i in range(start,end)]
    fare_list = []
    for d in date_range:
        try:
            fare_df = read_7C_1day_fare(dpt,arr,d)
            if fare_df is not None:
                fare_list.append(fare_df)
        except Exception as e:
            print('****** Error occured : ',e)
    result = pd.concat(fare_list,ignore_index=True)
    print('++++++++++Total : ', len(result))
    ## 파일 저장
    result.to_excel('{}/{}_{}_{}_{}_{}_{}.xls'.format('excel','7C',dpt,arr,start,end,datetime.today().strftime('%Y%m%d%H%m')))
    return result

# %%
dpt, arr, dpt_date = 'GMP','CJU','20170616'
crawling_ZE_data(dpt,arr,dpt_date)
# Out:
# Crawling eastarjet homepage schedule site
# Start Json Payload crawling :  https://www.eastarjet.com/json/dataService
# >> Parameters
# method:DataService.service , params:[{'inParameters': {'list': [{'data': {'list': [{'map': {'flightSearch': '{"viewType":"","fly_type":"2","person1":"1","person2":"0","person3":"0",    "residentCountry":"KR","currency":"","promotion_cd":"",    "flySection":[{"departure_cd":"GMP","arrival_cd":"CJU","departure_date_cd":"20170616"}]}'}, 'javaClass': 'java.util.Map'}], 'javaClass': 'java.util.List'}, 'structureType': 'FIELD', 'paramName': 'flightSearch', 'ioType': 'IN', 'javaClass': 'com.jein.framework.connectivity.parameter.InParameter'}], 'javaClass': 'java.util.List'}, 'sourceExtension': None, 'functionName': 'DTWBA00022', 'sourceName': None, 'javaClass': 'com.jein.framework.connectivity.parameter.RequestParameter', 'panelId': None, 'methodType': None, 'requestExecuteType': 'BIZ', 'requestUniqueCode': 'PGWBA00002', 'filterParameter': {'map': {}, 'javaClass': 'java.util.Map'}, 'DBTransaction': False}] , id:2 ,
# End Json Payload crawling
# {'id': 2,
#  'result': [{'javaClass': 'com.jein.framework.connectivity.parameter.OutParameter',
#    'name': 'OUT_DATA',
#    'resultData': [{'BizServiceResCode': 'S',
#      'FlightSearch': {'bookingCurrencyCode': 'KRW',
#       'lowFareAvailability': [[{'departureDate': '2017-06-13 00:00:00',
#          'destination': 'CJU',
#          'fareAmount': 11700,
#          'farePointAmount': 0,
#          'includeTaxesAndFees': False,
#          'noFlights': False,
#          'origin': 'GMP',
#          'taxesAndFeesAmount': 0},
#         {'departureDate': '2017-06-14 00:00:00',
#          'destination': 'CJU',
#          'fareAmount': 15900,
#          'farePointAmount': 0,
#          'includeTaxesAndFees': False,
#          'noFlights': False,
#          'origin': 'GMP',
#          'taxesAndFeesAmount': 0},
#         {'departureDate': '2017-06-15 00:00:00',
#          'destination': 'CJU',
#          'fareAmount': 34900,
#          'farePointAmount': 0,
#          'includeTaxesAndFees': False,
#          'noFlights': False,
#          'origin': 'GMP',
#          'taxesAndFeesAmount': 0},
#         {'departureDate': '2017-06-16 00:00:00',
#          'destination': 'CJU',
#          'fareAmount': 69900,
#          'farePointAmount': 0,
#          'includeTaxesAndFees': False,
#          'noFlights': False,
#          'origin': 'GMP',
#          'taxesAndFeesAmount': 0},
#         {'departureDate': '2017-06-17 00:00:00',
#          'destination': 'CJU',
#          'fareAmount': 35900,
#          'farePointAmount': 0,
#          'includeTaxesAndFees': False,
#          'noFlights': False,
#          'origin': 'GMP',
#          'taxesAndFeesAmount': 0},
#         {'departureDate': '2017-06-18 00:00:00',
#          'destination': 'CJU',
#          'fareAmount': 27900,
#          'farePointAmount': 0,
#          'includeTaxesAndFees': False,
#          'noFlights': False,
#          'origin': 'GMP',
#          'taxesAndFeesAmount': 0},
#         {'departureDate': '2017-06-19 00:00:00',
#          'destination': 'CJU',
#          'fareAmount': 19900,
#          'farePointAmount': 0,
#          'includeTaxesAndFees': False,
#          'noFlights': False,
#          'origin': 'GMP',
#          'taxesAndFeesAmount': 0}]],
#       'selectedOutboundDate': '2017-06-16 00:00:00',
#       'selectedReturnDate': '0001-01-01 00:00:00',
#       'trips': [[{'carrierCode': 'ZE',
#          'd_amount': 84900,
#          'd_classOfService': 'M',
#          'd_sellKey': '0~M~~MWSDC1~2015~~2~X',
#          'flightCodeShare': 'N',
#          'flightNumber': '251',
#          'flightNumberText': 'ZE251',
#          'h_amount': 84900,
#          'h_sellKey': '0~M~~MWSDCH~2015~~1~X',
#          'inftCnt': '11',
#          'isInternational': False,
#          'seatCnt': '145',
#          'sellKey': 'ZE~ 251~ ~~GMP~06/16/2017 06:10~CJU~06/16/2017 07:20~',
#          'standardTimeOfArrival': '20170616072000',
#          'standardTimeOfDeparture': '20170616061000',
#          'utcZeroDepartureTime': 201706152110,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'},
#         {'carrierCode': 'ZE',
#          'd_amount': 84900,
#          'd_classOfService': 'M',
#          'd_sellKey': '0~M~~MWSDC1~2015~~2~X',
#          'flightCodeShare': 'N',
#          'flightNumber': '201',
#          'flightNumberText': 'ZE201',
#          'h_amount': 84900,
#          'h_sellKey': '0~M~~MWSDCH~2015~~1~X',
#          'inftCnt': '14',
#          'isInternational': False,
#          'seatCnt': '137',
#          'sellKey': 'ZE~ 201~ ~~GMP~06/16/2017 06:15~CJU~06/16/2017 07:25~',
#          'standardTimeOfArrival': '20170616072500',
#          'standardTimeOfDeparture': '20170616061500',
#          'utcZeroDepartureTime': 201706152115,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'},
#         {'carrierCode': 'ZE',
#          'd_amount': 90900,
#          'd_classOfService': 'A',
#          'd_sellKey': '0~A~~AWSDC1~2015~~2~X',
#          'flightCodeShare': 'N',
#          'flightNumber': '281',
#          'flightNumberText': 'ZE281',
#          'h_amount': 90900,
#          'h_sellKey': '0~A~~AWSDCH~2015~~1~X',
#          'inftCnt': '13',
#          'isInternational': False,
#          'seatCnt': '139',
#          'sellKey': 'ZE~ 281~ ~~GMP~06/16/2017 06:20~CJU~06/16/2017 07:30~',
#          'standardTimeOfArrival': '20170616073000',
#          'standardTimeOfDeparture': '20170616062000',
#          'utcZeroDepartureTime': 201706152120,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'},
#         {'carrierCode': 'ZE',
#          'd_amount': 90900,
#          'd_classOfService': 'A',
#          'd_sellKey': '0~A~~AWSDC1~2015~~2~X',
#          'flightCodeShare': 'N',
#          'flightNumber': '203',
#          'flightNumberText': 'ZE203',
#          'h_amount': 90900,
#          'h_sellKey': '0~A~~AWSDCH~2015~~1~X',
#          'inftCnt': '14',
#          'isInternational': False,
#          'seatCnt': '116',
#          'sellKey': 'ZE~ 203~ ~~GMP~06/16/2017 06:50~CJU~06/16/2017 07:55~',
#          'standardTimeOfArrival': '20170616075500',
#          'standardTimeOfDeparture': '20170616065000',
#          'utcZeroDepartureTime': 201706152150,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'},
#         {'carrierCode': 'ZE',
#          'flightCodeShare': 'N',
#          'flightNumber': '205',
#          'flightNumberText': 'ZE205',
#          'inftCnt': '9',
#          'isInternational': False,
#          'seatCnt': '117',
#          'sellKey': 'ZE~ 205~ ~~GMP~06/16/2017 08:10~CJU~06/16/2017 09:20~',
#          'standardTimeOfArrival': '20170616092000',
#          'standardTimeOfDeparture': '20170616081000',
#          'utcZeroDepartureTime': 201706152310,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'},
#         {'carrierCode': 'ZE',
#          'flightCodeShare': 'N',
#          'flightNumber': '207',
#          'flightNumberText': 'ZE207',
#          'inftCnt': '11',
#          'isInternational': False,
#          'seatCnt': '143',
#          'sellKey': 'ZE~ 207~ ~~GMP~06/16/2017 09:50~CJU~06/16/2017 11:00~',
#          'standardTimeOfArrival': '20170616110000',
#          'standardTimeOfDeparture': '20170616095000',
#          'utcZeroDepartureTime': 201706160050,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'},
#         {'carrierCode': 'ZE',
#          'flightCodeShare': 'N',
#          'flightNumber': '209',
#          'flightNumberText': 'ZE209',
#          'inftCnt': '9',
#          'isInternational': False,
#          'seatCnt': '145',
#          'sellKey': 'ZE~ 209~ ~~GMP~06/16/2017 10:35~CJU~06/16/2017 11:45~',
#          'standardTimeOfArrival': '20170616114500',
#          'standardTimeOfDeparture': '20170616103500',
#          'utcZeroDepartureTime': 201706160135,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'},
#         {'carrierCode': 'ZE',
#          'flightCodeShare': 'N',
#          'flightNumber': '211',
#          'flightNumberText': 'ZE211',
#          'inftCnt': '12',
#          'isInternational': False,
#          'seatCnt': '145',
#          'sellKey': 'ZE~ 211~ ~~GMP~06/16/2017 11:20~CJU~06/16/2017 12:25~',
#          'standardTimeOfArrival': '20170616122500',
#          'standardTimeOfDeparture': '20170616112000',
#          'utcZeroDepartureTime': 201706160220,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'},
#         {'carrierCode': 'ZE',
#          'd_amount': 90900,
#          'd_classOfService': 'A',
#          'd_sellKey': '0~A~~AWSDC1~2015~~2~X',
#          'flightCodeShare': 'N',
#          'flightNumber': '213',
#          'flightNumberText': 'ZE213',
#          'h_amount': 90900,
#          'h_sellKey': '0~A~~AWSDCH~2015~~1~X',
#          'inftCnt': '13',
#          'isInternational': False,
#          'seatCnt': '123',
#          'sellKey': 'ZE~ 213~ ~~GMP~06/16/2017 11:50~CJU~06/16/2017 12:55~',
#          'standardTimeOfArrival': '20170616125500',
#          'standardTimeOfDeparture': '20170616115000',
#          'utcZeroDepartureTime': 201706160250,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'},
#         {'carrierCode': 'ZE',
#          'd_amount': 84900,
#          'd_classOfService': 'M',
#          'd_sellKey': '0~M~~MWSDC1~2015~~2~X',
#          'flightCodeShare': 'N',
#          'flightNumber': '273',
#          'flightNumberText': 'ZE273',
#          'h_amount': 84900,
#          'h_sellKey': '0~M~~MWSDCH~2015~~1~X',
#          'inftCnt': '12',
#          'isInternational': False,
#          'seatCnt': '145',
#          'sellKey': 'ZE~ 273~ ~~GMP~06/16/2017 12:50~CJU~06/16/2017 14:00~',
#          'standardTimeOfArrival': '20170616140000',
#          'standardTimeOfDeparture': '20170616125000',
#          'utcZeroDepartureTime': 201706160350,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'},
#         {'carrierCode': 'ZE',
#          'd_amount': 84900,
#          'd_classOfService': 'M',
#          'd_sellKey': '0~M~~MWSDC1~2015~~2~X',
#          'flightCodeShare': 'N',
#          'flightNumber': '215',
#          'flightNumberText': 'ZE215',
#          'h_amount': 84900,
#          'h_sellKey': '0~M~~MWSDCH~2015~~1~X',
#          'inftCnt': '13',
#          'isInternational': False,
#          'seatCnt': '122',
#          'sellKey': 'ZE~ 215~ ~~GMP~06/16/2017 12:55~CJU~06/16/2017 14:05~',
#          'standardTimeOfArrival': '20170616140500',
#          'standardTimeOfDeparture': '20170616125500',
#          'utcZeroDepartureTime': 201706160355,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'},
#         {'carrierCode': 'ZE',
#          'd_amount': 79900,
#          'd_classOfService': 'B',
#          'd_sellKey': '0~B~~BWSDC1~2015~~2~X',
#          'flightCodeShare': 'N',
#          'flightNumber': '217',
#          'flightNumberText': 'ZE217',
#          'h_amount': 79900,
#          'h_sellKey': '0~B~~BWSDCH~2015~~1~X',
#          'inftCnt': '12',
#          'isInternational': False,
#          'seatCnt': '142',
#          'sellKey': 'ZE~ 217~ ~~GMP~06/16/2017 14:35~CJU~06/16/2017 15:45~',
#          'standardTimeOfArrival': '20170616154500',
#          'standardTimeOfDeparture': '20170616143500',
#          'utcZeroDepartureTime': 201706160535,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'},
#         {'carrierCode': 'ZE',
#          'd_amount': 69900,
#          'd_classOfService': 'H',
#          'd_sellKey': '0~H~~HWSDC1~2015~~2~X',
#          'flightCodeShare': 'N',
#          'flightNumber': '219',
#          'flightNumberText': 'ZE219',
#          'h_amount': 69900,
#          'h_sellKey': '0~H~~HWSDCH~2015~~1~X',
#          'inftCnt': '14',
#          'isInternational': False,
#          'seatCnt': '121',
#          'sellKey': 'ZE~ 219~ ~~GMP~06/16/2017 15:40~CJU~06/16/2017 16:50~',
#          'standardTimeOfArrival': '20170616165000',
#          'standardTimeOfDeparture': '20170616154000',
#          'utcZeroDepartureTime': 201706160640,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'},
#         {'carrierCode': 'ZE',
#          'd_amount': 69900,
#          'd_classOfService': 'H',
#          'd_sellKey': '0~H~~HWSDC1~2015~~2~X',
#          'flightCodeShare': 'N',
#          'flightNumber': '221',
#          'flightNumberText': 'ZE221',
#          'h_amount': 69900,
#          'h_sellKey': '0~H~~HWSDCH~2015~~1~X',
#          'inftCnt': '12',
#          'isInternational': False,
#          'seatCnt': '140',
#          'sellKey': 'ZE~ 221~ ~~GMP~06/16/2017 15:55~CJU~06/16/2017 17:05~',
#          'standardTimeOfArrival': '20170616170500',
#          'standardTimeOfDeparture': '20170616155500',
#          'utcZeroDepartureTime': 201706160655,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'},
#         {'carrierCode': 'ZE',
#          'd_amount': 74900,
#          'd_classOfService': 'D',
#          'd_sellKey': '0~D~~DWSDC1~2015~~2~X',
#          'flightCodeShare': 'N',
#          'flightNumber': '223',
#          'flightNumberText': 'ZE223',
#          'h_amount': 74900,
#          'h_sellKey': '0~D~~DWSDCH~2015~~1~X',
#          'inftCnt': '13',
#          'isInternational': False,
#          'seatCnt': '121',
#          'sellKey': 'ZE~ 223~ ~~GMP~06/16/2017 16:35~CJU~06/16/2017 17:45~',
#          'standardTimeOfArrival': '20170616174500',
#          'standardTimeOfDeparture': '20170616163500',
#          'utcZeroDepartureTime': 201706160735,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'},
#         {'carrierCode': 'ZE',
#          'd_amount': 69900,
#          'd_classOfService': 'H',
#          'd_sellKey': '0~H~~HWSDC1~2015~~2~X',
#          'flightCodeShare': 'N',
#          'flightNumber': '257',
#          'flightNumberText': 'ZE257',
#          'h_amount': 69900,
#          'h_sellKey': '0~H~~HWSDCH~2015~~1~X',
#          'inftCnt': '15',
#          'isInternational': False,
#          'seatCnt': '145',
#          'sellKey': 'ZE~ 257~ ~~GMP~06/16/2017 18:10~CJU~06/16/2017 19:20~',
#          'standardTimeOfArrival': '20170616192000',
#          'standardTimeOfDeparture': '20170616181000',
#          'utcZeroDepartureTime': 201706160910,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'},
#         {'carrierCode': 'ZE',
#          'd_amount': 74900,
#          'd_classOfService': 'D',
#          'd_sellKey': '0~D~~DWSDC1~2015~~2~X',
#          'flightCodeShare': 'N',
#          'flightNumber': '225',
#          'flightNumberText': 'ZE225',
#          'h_amount': 74900,
#          'h_sellKey': '0~D~~DWSDCH~2015~~1~X',
#          'inftCnt': '15',
#          'isInternational': False,
#          'seatCnt': '139',
#          'sellKey': 'ZE~ 225~ ~~GMP~06/16/2017 18:35~CJU~06/16/2017 19:45~',
#          'standardTimeOfArrival': '20170616194500',
#          'standardTimeOfDeparture': '20170616183500',
#          'utcZeroDepartureTime': 201706160935,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'},
#         {'carrierCode': 'ZE',
#          'flightCodeShare': 'N',
#          'flightNumber': '227',
#          'flightNumberText': 'ZE227',
#          'inftCnt': '15',
#          'isInternational': False,
#          'seatCnt': '118',
#          'sellKey': 'ZE~ 227~ ~~GMP~06/16/2017 19:25~CJU~06/16/2017 20:35~',
#          'standardTimeOfArrival': '20170616203500',
#          'standardTimeOfDeparture': '20170616192500',
#          'utcZeroDepartureTime': 201706161025,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'},
#         {'carrierCode': 'ZE',
#          'flightCodeShare': 'N',
#          'flightNumber': '229',
#          'flightNumberText': 'ZE229',
#          'inftCnt': '14',
#          'isInternational': False,
#          'seatCnt': '145',
#          'sellKey': 'ZE~ 229~ ~~GMP~06/16/2017 19:45~CJU~06/16/2017 20:50~',
#          'standardTimeOfArrival': '20170616205000',
#          'standardTimeOfDeparture': '20170616194500',
#          'utcZeroDepartureTime': 201706161045,
#          'utcZeroNowTime': 201705250409,
#          'y_amount': 97900,
#          'y_classOfService': 'Y',
#          'y_sellKey': '0~Y~~YWSNF6~2015~~1~X',
#          'yh_amount': 97900,
#          'yh_sellKey': '0~Y~~YWSNFH6~2015~~1~X'}]]},
#      'flightSearchAuthKey': 'B1495685341020'}]},
#   {'javaClass': 'com.jein.framework.connectivity.parameter.OutParameter',
#    'name': 'SERVICE_STATUS',
#    'resultData': [{'DISPMSG': '',
#      'GUIDEMSG': '',
#      'LOGKEY': '',
#      'LOGMSG': '0',
#      'STATUS': 'S'}]}]}

# %%
## 하루치 데이터 읽어오기
dpt, arr, dpt_date = 'GMP','CJU','20170514'
read_7C_1day_fare(dpt,arr,dpt_date)
# Out:
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170514 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705140625 , DepStn:GMP , FltNo:151  , EquivFare:80000 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YW , ArrDate:201705140730 ,
# End Simple crawling
#          arr      date   dpt fare1  fare2  fare3     fare_basis   flt rbd  \
# 0       0730  20170514  0625     0  51900  80000             YW  151    Y
# 1       0740  20170514  0630     0  51900  80000             YW  101    Y
# 2       0810  20170514  0700     0  68900  80000             YW  103    Y
# 3       0900  20170514  0750     0  68900  80000             YW  105    Y
# 4       1010  20170514  0900     0  68900  80000             YW  107    Y
# 5       1055  20170514  0945     0  68900  80000             YW  141    Y
# 6       1115  20170514  1005     0  75900  80000             YW  111    Y
# 7       1335  20170514  1225     0  56900  80000             YW  115    Y
# 8       1350  20170514  1240     0  56900  80000             YW  117    Y
# 9       1425  20170514  1315     0  51900  80000             YW  143    Y
# 10      1505  20170514  1350     0  46900  80000             YW  119    Y
# 11      1550  20170514  1440     0  46900  80000             YW  121    Y
# 12      1640  20170514  1525     0  41900  80000             YW  155    Y
# 13      1655  20170514  1545     0  41900  80000             YW  123    Y
# 14      1715  20170514  1605     0  41900  80000             YW  125    Y
# 15      1755  20170514  1645     0  41900  80000             YW  145    Y
# 16      1925  20170514  1815     0  46900  80000             YW  127    Y
# 17      2015  20170514  1905     0  46900  80000             YW  129    Y
# 18      2045  20170514  1935     0  46900  80000             YW  133    Y
# 19      2135  20170514  2025     0  46900  80000             YW  147    Y
# 20  20170514       min   max  mean  41900  80000  60342.8571429
#
#    seat  tax1  tax2
# 0     9  2200  4000
# 1     9  2200  4000
# 2     9  2200  4000
# 3     9  2200  4000
# 4     9  2200  4000
# 5     9  2200  4000
# 6     9  2200  4000
# 7     9  2200  4000
# 8     9  2200  4000
# 9     9  2200  4000
# 10    9  2200  4000
# 11    9  2200  4000
# 12    9  2200  4000
# 13    9  2200  4000
# 14    9  2200  4000
# 15    9  2200  4000
# 16    9  2200  4000
# 17    9  2200  4000
# 18    9  2200  4000
# 19    9  2200  4000
# 20

# %%
## 정해진 기간의 데이터 읽어오기
dpt, arr = 'GMP','CJU'
start,end =0, 31 ## 읽어올 데이터 기간
read_7C_date_range_fare(dpt,arr,start,end)
# Out:
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170424 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201704241440 , DepStn:GMP , FltNo:121  , EquivFare:65600 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YX , ArrDate:201704241550 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170425 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201704250625 , DepStn:GMP , FltNo:151  , EquivFare:65600 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YX , ArrDate:201704250730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170426 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201704260625 , DepStn:GMP , FltNo:151  , EquivFare:65600 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YX , ArrDate:201704260730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170427 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201704270625 , DepStn:GMP , FltNo:151  , EquivFare:65600 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YX , ArrDate:201704270730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170428 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# ********** No Data Type 2 **********
# ****** Error occured :  zero-size array to reduction operation minimum which has no identity
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170429 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# ********** No Data Type 2 **********
# ****** Error occured :  zero-size array to reduction operation minimum which has no identity
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170430 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201704301645 , DepStn:GMP , FltNo:145  , EquivFare:97700 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YH , ArrDate:201704301755 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170501 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705010620 , DepStn:GMP , FltNo:161  , EquivFare:97700 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YH , ArrDate:201705010730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170502 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705020620 , DepStn:GMP , FltNo:161  , EquivFare:97700 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YH , ArrDate:201705020730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170503 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# ********** No Data Type 2 **********
# ****** Error occured :  zero-size array to reduction operation minimum which has no identity
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170504 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705040625 , DepStn:GMP , FltNo:151  , EquivFare:97700 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YH , ArrDate:201705040730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170505 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705051545 , DepStn:GMP , FltNo:123  , EquivFare:97700 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YH , ArrDate:201705051655 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170506 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705060625 , DepStn:GMP , FltNo:151  , EquivFare:97700 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YH , ArrDate:201705060730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170507 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705070620 , DepStn:GMP , FltNo:161  , EquivFare:97700 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YH , ArrDate:201705070730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170508 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705080620 , DepStn:GMP , FltNo:161  , EquivFare:97700 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YH , ArrDate:201705080730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170509 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705090625 , DepStn:GMP , FltNo:151  , EquivFare:65600 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YX , ArrDate:201705090730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170510 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705100625 , DepStn:GMP , FltNo:151  , EquivFare:65600 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YX , ArrDate:201705100730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170511 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# ********** No Data Type 1 **********
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170512 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705120625 , DepStn:GMP , FltNo:151  , EquivFare:97700 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YP , ArrDate:201705120730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170513 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705130625 , DepStn:GMP , FltNo:151  , EquivFare:97700 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YP , ArrDate:201705130730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170514 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705140625 , DepStn:GMP , FltNo:151  , EquivFare:80000 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YW , ArrDate:201705140730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170515 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705150625 , DepStn:GMP , FltNo:151  , EquivFare:65600 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YX , ArrDate:201705150730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170516 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705160625 , DepStn:GMP , FltNo:151  , EquivFare:65600 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YX , ArrDate:201705160730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170517 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705170625 , DepStn:GMP , FltNo:151  , EquivFare:65600 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YX , ArrDate:201705170730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170518 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705180625 , DepStn:GMP , FltNo:151  , EquivFare:65600 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YX , ArrDate:201705180730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170519 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705190625 , DepStn:GMP , FltNo:151  , EquivFare:97700 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YP , ArrDate:201705190730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170520 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201705200625 , DepStn:GMP , FltNo:151  , EquivFare:97700 , RBD:Y , RouteType:D , TripType:OW , FareBasis:YP , ArrDate:201705200730 ,
# End Simple crawling
# Crawling jejuair homepage schedule site
# Start Session crawling
# make session :  https://www.jejuair.net/jejuair/com/jeju/ibe/availInit.do
# crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchAvail.do
# >> Parameters
# ArrStn:CJU , RouteType:D , Language:KR , TripType:OW , SystemType:IBE , Index:1 , AdultPaxCnt:1 , DepDate:20170521 , InfantPaxCnt:0 , SegType:DEP , ChildPaxCnt:0 , DepStn:GMP ,
# End Session crawling
# Start Simple crawling :  https://www.jejuair.net/jejuair/com/jeju/ibe/searchFareTax.do
# >> Parameters
# ArrStn:CJU , FareTypeNo:3 , DepDate:201