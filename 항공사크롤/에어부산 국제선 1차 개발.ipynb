# %% [markdown]
# ## 김포 제주 노선 가격 정보 읽어오기
# - 대상 사이트 : 에어부산 웹사이트

# %% [markdown]
# ### 에어부산 사이트 웹 크롤링
#     - 에어부산 국제선 항공권예매 페이지를 이용한 크롤링
#     - 기본 크롤링
#     - 필요 데이터 추출 하여 Pandas 의 DataFrame 형태로 생성
#     - 생성된 데이터 엑셀 파일로 저장

# %%
from IPython.display import display
import requests
import pandas as pd
import numpy as np
from pandas import DataFrame
from bs4 import BeautifulSoup
import time
from datetime import datetime
from datetime import timedelta
from common.crawling_util import simple_crawling
from common.parsing_util import parsing_json_data_to_dict,mining_value_by_last_field_name
from common.parsing_util import r_flatten,stat_fare
from common.util import fill_list

def crawling_BX_data(dpt,arr,dpt_date):
    ##출발지, 도착지, 출발일을 기준으로 국내선(국제선) 편도 가격 읽어오기
    print('Crawling airbusan homepage schedule site')
    url = "https://www.airbusan.com/web/bookingApi/internationalOnewayAvail"
    head = {
        'Referer':'https://www.airbusan.com/web/individual/booking/international',
    }
    param ={## depDate 포맷 체크 필요 YYYY-MM-DD
    'jsonString':'{"bookingCategory":"Individual","tripType":"OW","listItinerary":\
    [{"itinNo":"1","depCity":"'+dpt+'","arrCity":"'+arr+'","depDate":"'+dpt_date+'","itineraryType":"Going"}],\
    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"}'
    }

    return simple_crawling(url,param,head=head,method='post',json=True)

data_heads = ['date','flt','start','end','cls','fare','tax1','tax2','seat']
key_fields = ['flightNo','depTime','arrTime','cls','priceAd','avail']
## Tax Info :  json['pubTaxFuel']['fuelAd'],json['pubTaxFuel']['taxAd']
## raw 데이터로 부터 DataFrame 생성
def raw_to_df(raw_data):
    df_list = []
    for list_flight in raw_data['listFareIntAvail'][0]['listFlight']:
        df_dict = mining_value_by_last_field_name(list_flight,key_fields)
        max_len = max(len(d) for d in df_dict.values())
        for k,v in df_dict.items():
            if len(v) < max_len:
                df_dict[k] = fill_list(v,max_len,method='bfill')
        df = pd.DataFrame(df_dict,columns=key_fields)
        df.columns = ['flt','start','end','cls','fare','seat']
        df_list.append(df)
    result_df = pd.concat(df_list,ignore_index=True)
    result_df['date'] = raw_data['listFareIntAvail'][0]['depDate']
    result_df['tax1'] = raw_data['pubTaxFuel']['fuelAd']
    result_df['tax2'] = raw_data['pubTaxFuel']['taxAd']
    return result_df[data_heads]

## 하루 기준 가격정보, 텍스정보, 최소값, 최대값, 평균 DataFrame 생성
def read_BX_1day_fare(dpt,arr,dpt_date):
    ## 데이터 읽어오기
    raw_data = crawling_BX_data(dpt,arr,dpt_date)
    df=raw_to_df(raw_data)
    if df is None or len(df) == 0: ## 읽는 도중 에러가 나거나 익셉션 발생으로 문제가 있을 경우 처리
        print('********** No Data On raw_to_df **********')
        return None

    ## 최소값 최대값 평균 계산
    stat = stat_fare(df,['fare'])
    ## 요약정보 추가
    df.ix[len(df)] = [dpt_date,'min','max','mean',str(stat[0]),str(stat[1]),str(stat[2]),'','']
    return df

## 정해진 기간의 데이터 읽어오기, 기본 30일
def read_BX_date_range_fare(dpt,arr,start=0,end=31):
    # 기본 30일간 데이터 읽어서 파일로 저장
    date_range = [ (datetime.today()+timedelta(1)*i).strftime('%Y%m%d') for i in range(start,end)]
    df_list = []
    for d in date_range:
        try:
            fare_df = read_BX_1day_fare(dpt,arr,d)
            if fare_df is not None:
                df_list.append(fare_df)
        except Exception as e:
            print('****** Error occured : ',e)
    result = pd.concat(df_list,ignore_index=True)
    print('++++++++++Total : ', len(result))
    ## 파일 저장
    result.to_excel('{}/{}_{}_{}_{}_{}_{}.xls'.format('excel','BX',dpt,arr,start,end,datetime.today().strftime('%Y%m%d%H%M')))
    return result

# %%
dpt, arr, dpt_date = 'PUS','NRT','20170520'
json=crawling_BX_data(dpt,arr,dpt_date)
raw_to_df(json)
# Out:
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170520","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
#        date     flt start   end cls      fare  tax1     tax2  seat
# 0  20170520  BX0112  1100  1300   L  130000.0   0.0  23000.0    41
# 1  20170520  BX0112  1100  1300   S  200000.0   0.0  23000.0    20
# 2  20170520  BX0114  1435  1635   A  100000.0   0.0  23000.0    19
# 3  20170520  BX0114  1435  1635   L  110000.0   0.0  23000.0    59
# 4  20170520  BX0114  1435  1635   S  200000.0   0.0  23000.0    20

# %%
## 하루치 데이터 읽어오기
dpt, arr, dpt_date = 'PUS','NRT','20170520'
#dpt, arr, dpt_date, dom_int = 'ICN','NRT','2017-05-01','I'

read_BX_1day_fare(dpt,arr,dpt_date)
# Out:
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170520","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# D:\python\mynotebook\AirlineFareCrawlingProject\common\parsing_util.py:27: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if '' in fare_arr or '0' in fare_arr:
#        date     flt start   end       cls      fare      tax1   tax2 seat
# 0  20170520  BX0112  1100  1300         L    130000         0  23000   41
# 1  20170520  BX0112  1100  1300         S    200000         0  23000   20
# 2  20170520  BX0114  1435  1635         A    100000         0  23000   19
# 3  20170520  BX0114  1435  1635         L    110000         0  23000   59
# 4  20170520  BX0114  1435  1635         S    200000         0  23000   20
# 5  20170520     min   max  mean  100000.0  200000.0  135000.0

# %%
## 정해진 기간의 데이터 읽어오기
dpt, arr, = 'PUS','NRT'
start,end = 0, 31 ## 읽어올 데이터 기간
read_BX_date_range_fare(dpt,arr,start,end)
# Out:
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170508","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# ****** Error occured :  No objects to concatenate
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170509","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170510","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# D:\python\mynotebook\AirlineFareCrawlingProject\common\parsing_util.py:27: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if '' in fare_arr or '0' in fare_arr:
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170511","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170512","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170513","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170514","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170515","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170516","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170517","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170518","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170519","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170520","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170521","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170522","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170523","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170524","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170525","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170526","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170527","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170528","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170529","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170530","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170531","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170601","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170602","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170603","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170604","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170605","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170606","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170607","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# ++++++++++Total :  196
#          date     flt start   end       cls      fare           tax1   tax2  \
# 0    20170509  BX0112  1100  1300         A    100000              0  23000
# 1    20170509  BX0112  1100  1300         L    120000              0  23000
# 2    20170509  BX0112  1100  1300         S    200000              0  23000
# 3    20170509  BX0114  1435  1635         A     90000              0  23000
# 4    20170509  BX0114  1435  1635         L    110000              0  23000
# 5    20170509  BX0114  1435  1635         S    200000              0  23000
# 6    20170509     min   max  mean   90000.0  200000.0       124000.0
# 7    20170510  BX0112  1100  1300         A     80000              0  23000
# 8    20170510  BX0112  1100  1300         L    110000              0  23000
# 9    20170510  BX0112  1100  1300         S    200000              0  23000
# 10   20170510  BX0114  1435  1635         A     60000              0  23000
# 11   20170510  BX0114  1435  1635         L    110000              0  23000
# 12   20170510  BX0114  1435  1635         S    200000              0  23000
# 13   20170510     min   max  mean   60000.0  200000.0       112500.0
# 14   20170511  BX0112  1100  1300         L    110000              0  23000
# 15   20170511  BX0112  1100  1300         S    200000              0  23000
# 16   20170511  BX0114  1435  1635         A     80000              0  23000
# 17   20170511  BX0114  1435  1635         L    110000              0  23000
# 18   20170511  BX0114  1435  1635         S    200000              0  23000
# 19   20170511     min   max  mean   80000.0  200000.0       130000.0
# 20   20170512  BX0112  1100  1300         L    120000              0  23000
# 21   20170512  BX0112  1100  1300         S    200000              0  23000
# 22   20170512  BX0114  1435  1635         A     80000              0  23000
# 23   20170512  BX0114  1435  1635         L    110000              0  23000
# 24   20170512  BX0114  1435  1635         S    200000              0  23000
# 25   20170512     min   max  mean   80000.0  200000.0       127500.0
# 26   20170513  BX0112  1100  1300         A    100000              0  23000
# 27   20170513  BX0112  1100  1300         L    120000              0  23000
# 28   20170513  BX0112  1100  1300         S    200000              0  23000
# 29   20170513  BX0114  1435  1635         A     80000              0  23000
# ..        ...     ...   ...   ...       ...       ...            ...    ...
# 166  20170603  BX0114  1435  1635         L    140000              0  23000
# 167  20170603  BX0114  1435  1635         S    200000              0  23000
# 168  20170603     min   max  mean  140000.0  220000.0  186666.666667
# 169  20170604  BX0112  1100  1300         L    130000              0  23000
# 170  20170604  BX0112  1100  1300         S    200000              0  23000
# 171  20170604  BX0114  1435  1635         A    100000              0  23000
# 172  20170604  BX0114  1435  1635         L    110000              0  23000
# 173  20170604  BX0114  1435  1635         S    200000              0  23000
# 174  20170604     min   max  mean  100000.0  200000.0       135000.0
# 175  20170605  BX0112  1100  1300         A    100000              0  23000
# 176  20170605  BX0112  1100  1300         L    110000              0  23000
# 177  20170605  BX0112  1100  1300         S    200000              0  23000
# 178  20170605  BX0114  1435  1635         A     80000              0  23000
# 179  20170605  BX0114  1435  1635         L    110000              0  23000
# 180  20170605  BX0114  1435  1635         S    200000              0  23000
# 181  20170605     min   max  mean   80000.0  200000.0       122500.0
# 182  20170606  BX0112  1100  1300         A    100000              0  23000
# 183  20170606  BX0112  1100  1300         L    110000              0  23000
# 184  20170606  BX0112  1100  1300         S    200000              0  23000
# 185  20170606  BX0114  1435  1635         A     60000              0  23000
# 186  20170606  BX0114  1435  1635         L    110000              0  23000
# 187  20170606  BX0114  1435  1635         S    200000              0  23000
# 188  20170606     min   max  mean   60000.0  200000.0       117500.0
# 189  20170607  BX0112  1100  1300         A     70000              0  23000
# 190  20170607  BX0112  1100  1300         L    110000              0  23000
# 191  20170607  BX0112  1100  1300         S    200000              0  23000
# 192  20170607  BX0114  1435  1635         A     60000              0  23000
# 193  20170607  BX0114  1435  1635         L    110000              0  23000
# 194  20170607  BX0114  1435  1635         S    200000              0  23000
# 195  20170607     min   max  mean   60000.0  200000.0       110000.0
#
#     seat
# 0      6
# 1     34
# 2     20
# 3     37
# 4     49
# 5     20
# 6
# 7     50
# 8     40
# 9     40
# 10    67
# 11    69
# 12    20
# 13
# 14    45
# 15    10
# 16    59
# 17    59
# 18    20
# 19
# 20    46
# 21    10
# 22    41
# 23    69
# 24    19
# 25
# 26     4
# 27    90
# 28    20
# 29    40
# ..   ...
# 166   61
# 167   40
# 168
# 169   72
# 170   40
# 171   16
# 172   67
# 173   60
# 174
# 175   16
# 176   60
# 177   40
# 178   65
# 179   70
# 180   20
# 181
# 182   13
# 183   40
# 184   10
# 185   78
# 186   69
# 187   20
# 188
# 189   53
# 190   60
# 191   40
# 192   84
# 193   70
# 194   20
# 195
#
# [196 rows x 9 columns]

# %%
## 정해진 기간의 데이터 읽어오기
dpt, arr, = 'PUS','NRT'
start,end = 31, 46 ## 읽어올 데이터 기간
read_BX_date_range_fare(dpt,arr,start,end)
# Out:
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170608","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170609","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# D:\python\mynotebook\AirlineFareCrawlingProject\common\parsing_util.py:27: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if '' in fare_arr or '0' in fare_arr:
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170610","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170611","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170612","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170613","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170614","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170615","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170616","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170617","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170618","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170619","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170620","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170621","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170622","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# ++++++++++Total :  101
#          date     flt start   end      cls      fare      tax1   tax2 seat
# 0    20170608  BX0112  1100  1300        A     80000         0  23000   52
# 1    20170608  BX0112  1100  1300        L    110000         0  23000   60
# 2    20170608  BX0112  1100  1300        S    200000         0  23000   40
# 3    20170608  BX0114  1435  1635        A     60000         0  23000   79
# 4    20170608  BX0114  1435  1635        L    110000         0  23000   70
# 5    20170608  BX0114  1435  1635        S    200000         0  23000   20
# 6    20170608     min   max  mean  60000.0  200000.0  112500.0
# 7    20170609  BX0112  1100  1300        L    120000         0  23000   35
# 8    20170609  BX0112  1100  1300        S    200000         0  23000   20
# 9    20170609  BX0114  1435  1635        A     90000         0  23000   33
# 10   20170609  BX0114  1435  1635        L    110000         0  23000   70
# 11   20170609  BX0114  1435  1635        S    200000         0  23000   20
# 12   20170609     min   max  mean  90000.0  200000.0  130000.0
# 13   20170610  BX0112  1100  1300        L    110000         0  23000   55
# 14   20170610  BX0112  1100  1300        S    200000         0  23000   20
# 15   20170610  BX0114  1435  1635        A     80000         0  23000   39
# 16   20170610  BX0114  1435  1635        L    110000         0  23000   70
# 17   20170610  BX0114  1435  1635        S    200000         0  23000   20
# 18   20170610     min   max  mean  80000.0  200000.0  130000.0
# 19   20170611  BX0112  1100  1300        A     80000         0  23000   39
# 20   20170611  BX0112  1100  1300        L    110000         0  23000   60
# 21   20170611  BX0112  1100  1300        S    200000         0  23000   38
# 22   20170611  BX0114  1435  1635        A     80000         0  23000   27
# 23   20170611  BX0114  1435  1635        L    110000         0  23000   70
# 24   20170611  BX0114  1435  1635        S    200000         0  23000   20
# 25   20170611     min   max  mean  80000.0  200000.0  130000.0
# 26   20170612  BX0112  1100  1300        A    100000         0  23000   15
# 27   20170612  BX0112  1100  1300        L    110000         0  23000   60
# 28   20170612  BX0112  1100  1300        S    200000         0  23000   40
# 29   20170612  BX0114  1435  1635        A     70000         0  23000   43
# ..        ...     ...   ...   ...      ...       ...       ...    ...  ...
# 71   20170618  BX0114  1435  1635        S    200000         0  23000   20
# 72   20170618     min   max  mean  80000.0  200000.0  120000.0
# 73   20170619  BX0112  1100  1300        A     80000         0  23000   57
# 74   20170619  BX0112  1100  1300        L    110000         0  23000   60
# 75   20170619  BX0112  1100  1300        S    200000         0  23000   40
# 76   20170619  BX0114  1435  1635        A     70000         0  23000   73
# 77   20170619  BX0114  1435  1635        L    110000         0  23000   70
# 78   20170619  BX0114  1435  1635        S    200000         0  23000   20
# 79   20170619     min   max  mean  70000.0  200000.0  115000.0
# 80   20170620  BX0112  1100  1300        A     70000         0  23000   41
# 81   20170620  BX0112  1100  1300        L    110000         0  23000   60
# 82   20170620  BX0112  1100  1300        S    200000         0  23000   40
# 83   20170620  BX0114  1435  1635        A     60000         0  23000   83
# 84   20170620  BX0114  1435  1635        L    110000         0  23000   70
# 85   20170620  BX0114  1435  1635        S    200000         0  23000   20
# 86   20170620     min   max  mean  60000.0  200000.0  110000.0
# 87   20170621  BX0112  1100  1300        A     80000         0  23000   28
# 88   20170621  BX0112  1100  1300        L    110000         0  23000   60
# 89   20170621  BX0112  1100  1300        S    200000         0  23000   40
# 90   20170621  BX0114  1435  1635        A     60000         0  23000   61
# 91   20170621  BX0114  1435  1635        L    110000         0  23000   70
# 92   20170621  BX0114  1435  1635        S    200000         0  23000   20
# 93   20170621     min   max  mean  60000.0  200000.0  112500.0
# 94   20170622  BX0112  1100  1300        A    100000         0  23000   22
# 95   20170622  BX0112  1100  1300        L    110000         0  23000   56
# 96   20170622  BX0112  1100  1300        S    200000         0  23000   40
# 97   20170622  BX0114  1435  1635        A     70000         0  23000   42
# 98   20170622  BX0114  1435  1635        L    110000         0  23000   69
# 99   20170622  BX0114  1435  1635        S    200000         0  23000   20
# 100  20170622     min   max  mean  70000.0  200000.0  120000.0
#
# [101 rows x 9 columns]

# %%
## 정해진 기간의 데이터 읽어오기
dpt, arr, = 'PUS','NRT'
start,end = 46, 90 ## 읽어올 데이터 기간
read_BX_date_range_fare(dpt,arr,start,end)
# Out:
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170623","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170624","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# D:\python\mynotebook\AirlineFareCrawlingProject\common\parsing_util.py:27: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if '' in fare_arr or '0' in fare_arr:
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170625","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170626","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170627","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170628","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170629","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170630","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170701","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170702","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170703","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170704","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170705","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170706","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170707","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170708","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170709","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170710","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170711","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170712","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170713","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170714","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170715","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170716","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170717","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170718","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170719","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170720","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170721","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170722","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170723","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170724","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170725","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170726","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170727","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170728","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170729","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170730","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170731","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170801","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170802","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170803","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170804","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# Crawling airbusan homepage schedule site
# Start Simple crawling :  https://www.airbusan.com/web/bookingApi/internationalOnewayAvail
# >> Parameters
# jsonString:{"bookingCategory":"Individual","tripType":"OW","listItinerary":    [{"itinNo":"1","depCity":"PUS","arrCity":"NRT","depDate":"20170805","itineraryType":"Going"}],    "focYN":"N","openReturnYN":"","paxCountCorp":0,"paxCountAd":1,"paxCountCh":0,"paxCountIn":0,"itinNo":"1"} ,
# End Simple crawling
# ++++++++++Total :  285
#          date     flt start   end       cls      fare           tax1   tax2  \
# 0    20170623  BX0112  1100  1300         A    100000              0  23000
# 1    20170623  BX0112  1100  1300         L    110000              0  23000
# 2    20170623  BX0112  1100  1300         S    200000              0  23000
# 3    20170623  BX0114  1435  1635         A     80000              0  23000
# 4    20170623  BX0114  1435  1635         L    110000              0  23000
# 5    20170623  BX0114  1435  1635         S    200000              0  23000
# 6    20170623     min   max  mean   80000.0  200000.0       122500.0
# 7    20170624  BX0112  1100  1300         A    100000              0  23000
# 8    20170624  BX0112  1100  1300         L    110000              0  23000
# 9    20170624  BX0112  1100  1300         S    200000              0  23000
# 10   20170624  BX0114  1435  1635         A     80000              0  23000
# 11   20170624  BX0114  1435  1635         L    110000              0  23000
# 12   20170624  BX0114  1435  1635         S    200000              0  23000
# 13   20170624     min   max  mean   80000.0  200000.0       122500.0
# 14   20170625  BX0112  1100  1300         A     90000              0  23000
# 15   20170625  BX0112  1100  1300         L    110000              0  23000
# 16   20170625  BX0112  1100  1300         S    200000              0  23000
# 17   20170625  BX0114  1435  1635         A     80000              0  23000
# 18   20170625  BX0114  1435  1635         L    110000              0  23000
# 19   20170625  BX0114  1435  1635         S    200000              0  23000
# 20   20170625     min   max  mean   80000.0  200000.0       120000.0
# 21   20170626  BX0112  1100  1300         A    100000              0  23000
# 22   20170626  BX0112  1100  1300         L    110000              0  23000
# 23   20170626  BX0112  1100  1300         S    200000              0  23000
# 24   20170626  BX0114  1435  1635         A     70000              0  23000
# 25   20170626  BX0114  1435  1635         L    110000              0  23000
# 26   20170626  BX0114  1435  1635         S    200000              0  23000
# 27   20170626     min   max  mean   70000.0  200000.0       120000.0
# 28   20170627  BX0112  1100  1300         A     70000              0  23000
# 29   20170627  BX0112  1100  1300         L    110000              0  23000
# ..        ...     ...   ...   ...       ...       ...            ...    ...
# 255  20170731  BX0112  1100  1300         S    200000              0  23000
# 256  20170731  BX0114  1435  1635         L    130000              0  23000
# 257  20170731  BX0114  1435  1635         S    200000              0  23000
# 258  20170731     min   max  mean  120000.0  200000.0       150000.0
# 259  20170801  BX0112  1100  1300         L    130000              0  23000
# 260  20170801  BX0112  1100  1300         S    200000              0  23000
# 261  20170801  BX0114  1435  1635         L    120000              0  23000
# 262  20170801  BX0114  1435  1635         S    200000              0  23000
# 263  20170801     min   max  mean  120000.0  200000.0       150000.0
# 264  20170802  BX0112  1100  1300         L    110000              0  23000
# 265  20170802  BX0112  1100  1300         S    200000              0  23000
# 266  20170802  BX0114  1435  1635         L    120000              0  23000
# 267  20170802  BX0114  1435  1635         S    200000              0  23000
# 268  20170802     min   max  mean  110000.0  200000.0  143333.333333
# 269  20170803  BX0112  1100  1300         L    130000              0  23000
# 270  20170803  BX0112  1100  1300         S    200000              0  23000
# 271  20170803  BX0114  1435  1635         L    130000              0  23000
# 272  20170803  BX0114  1435  1635         S    200000              0  23000
# 273  20170803     min   max  mean  130000.0  200000.0       165000.0
# 274  20170804  BX0112  1100  1300         L    120000              0  23000
# 275  20170804  BX0112  1100  1300         S    200000              0  23000
# 276  20170804  BX0114  1435  1635         L    120000              0  23000
# 277  20170804  BX0114  1435  1635         S    200000              0  23000
# 278  20170804     min   max  mean  120000.0  200000.0       160000.0
# 279  20170805  BX0112  1100  1300         A     90000              0  23000
# 280  20170805  BX0112  1100  1300         L    110000              0  23000
# 281  20170805  BX0112  1100  1300         S    200000              0  23000
# 282  20170805  BX0114  1435  1635         L    130000              0  23000
# 283  20170805  BX0114  1435  1635         S    200000              0  23000
# 284  20170805     min   max  mean   90000.0  200000.0       132500.0
#
#     seat
# 0     22
# 1     70
# 2     20
# 3     42
# 4     70
# 5     20
# 6
# 7      9
# 8     57
# 9     20
# 10    34
# 11    67
# 12    20
# 13
# 14    32
# 15    60
# 16    40
# 17    36
# 18    70
# 19    20
# 20
# 21    18
# 22    60
# 23    40
# 24    64
# 25    70
# 26    20
# 27
# 28    49
# 29    60
# ..   ...
# 255   40
# 256   40
# 257   60
# 258
# 259   31
# 260   20
# 261   57
# 262   20
# 263
# 264   61
# 265   20
# 266   77
# 267   20
# 268
# 269   39
# 270   30
# 271   48
# 272   20
# 273
# 274   54
# 275   29
# 276   60
# 277   20
# 278
# 279   15
# 280   48
# 281   60
# 282   46
# 283   40
# 284
#
# [285 rows x 9 columns]
