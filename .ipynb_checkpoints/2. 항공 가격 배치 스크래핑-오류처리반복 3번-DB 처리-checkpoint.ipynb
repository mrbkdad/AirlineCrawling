# %% [markdown]
# ## 항공가격 배치 스크래핑
# - 크롤링 배치 처리 파일 스크래핑 처리
#     * 전체 파일 스크래핑 처리
#     * 미처리 파일 오류 처리 3회 실시
#     * 스크래핑 처리 파일 DB 처리

# %%
from collections import namedtuple
from datetime import datetime, timedelta
import requests
import sqlite3
import csv, io, os
from common.env_variable import *
from common.batch_util import *
from common.scrap_func import *
from common.crawl_func import *
from common.log_util import *
from common.util import save_raw_data
## 로그 초기화
logger_initialize('scrap_logger_setting.json')
init_env_variable('common/env_variable.json')

# %%
## 국내선 국제선 구분하여 폴더에 있는 파일 scraping 처리
## 포맷 : 대상항공사코드,플라이트,출발일,출발지,도착지,출발시간,도착시간,가격,유류세,세금,좌석수
## 오류 발생한 파일들은 해당 폴더에 그대로 방치, 주기적으로 체크하여 오래 남아 있는 파일들은 문제있는 파일로 취급 하여 재처리
def batch_scrap(crawl_dir,scrap_data_dir,dom_int=None):
    start_time = datetime.today()
    log_msgs = ['start batch job','scraping crawled file']
    log(log_msgs,level=logging.INFO)
    scrap_cnt = 0
    ## 스크랩 대상 파일(파일명, 내용)
    crawl_dir = crawl_dir
    files = get_crawled_file_list(crawl_dir)
    for file in files:
        log(file,level=logging.DEBUG)
        scrap_file = crawl_dir+'/'+file
        head, raw_data = read_crawled_file(scrap_file)
        ## 헤더 정보 읽어오기
        #head = get_headinfo(raw_data.splitlines()[0])
        log([head['dom_int'],head['site_code']],level=logging.DEBUG)
        if dom_int is not None and head['dom_int'] != dom_int: ## 국내선/국제선 체크
            continue
        site_code = head['site_code']
        ## 해당 함수 생성
        func = get_scrap_site_func(head['dom_int'],head['site_code'])
        log(['check func',func],level=logging.DEBUG)
        if func is None: ## 해당 함수가 없을 경우 다음으로
            continue
        try:
            scraped_list = func(head,raw_data)#''.join(raw_data.splitlines()[1:])))
        except:
            log_msgs = ['Error occured when doing scrap func -',func]
            log(log_msgs,level=logging.ERROR)
            continue
            
        ## 스크래핑 실패시 해당 파일 폴더에 보관, 해당 폴더 모니터링시 장기 미처리 파일 체크하여 처리
        if scraped_list is None:
            ## 출렬 처리
            log('Error occured in {}!'.format(file),level=logging.DEBUG)
            continue
        ## CSV 처리
        scraped_list_to_csv(set_headinfo(**head),scraped_list,scrap_data_dir+"/"+file.split(".")[0]+".csv")
        ## 처리 파일 이동 처리
        ## 이동 처리시 이미 파일이 존재하는 경우 삭제후 처리
        if os.path.exists(os.path.join(SCRAP_OK_DIR,os.path.split(scrap_file)[-1])):
            os.remove(os.path.join(SCRAP_OK_DIR,os.path.split(scrap_file)[-1]))
        move_scraped_file(scrap_file,SCRAP_OK_DIR)
        scrap_cnt += 1

    end_time = datetime.today()
    log_msgs = ['end batch job','scraping crawled file',
                'elapsed -{}'.format(end_time-start_time),'Total crawl:{} files saved.'.format(scrap_cnt)]
    log(log_msgs,level=logging.INFO)
## 에러 파일 추가 크롤링 처리
def batch_error(crawl_dir):
    ## 에러 파일 추가 크롤링 처리
    log('start recrawling batch job for error files')
    files = get_crawled_file_list(crawl_dir)
    cnt = 0
    for file in files:
        log(['error file',file])
        head,_=read_crawled_file(crawl_dir+'/'+file)
        func,isairline=get_crawl_site_func(head['dom_int'],head['site_code'])
        if isairline:
            raw_data = crawling_func(func,head['dpt'],head['arr'],head['dpt_date'])
            new_file = file_name(head['site_code'],head['dpt'],head['arr'],head['dpt_date'])
            new_head = set_headinfo(head['site_code'],head['dom_int'],head['site_code'],head['dpt'],head['arr'],
                                head['dpt_date'],crawl_date=head['crawl_date'])
        else:
            raw_data = crawling_func(func,head['airline'],head['dpt'],head['arr'],head['dpt_date'])
            new_file = file_name(head['site_code'],head['dpt'],head['arr'],head['dpt_date'],airline=head['airline'])
            new_head = set_headinfo(head['site_code'],head['dom_int'],head['airline'],head['dpt'],head['arr'],
                                head['dpt_date'],crawl_date=head['crawl_date'])
        ## 처리 파일 이동 : 해당 폴더의 error 폴더로 이동 처리
        ## 파일 명이 중복되는 경우 발생 가능, 이동 처리후 저장
        move_scraped_file(crawl_dir+'/'+file,crawl_dir+'/error')
        save_raw_data(new_file,raw_data,head=new_head)
        cnt += 1
    log(['end recrawling batch job','total {} files saved!'.format(cnt)])
## 파일 배치 처리
def batch_db(scrap_dir,db_ok_dir,db):
    start_time = datetime.today()
    log_msgs = ['start batch job','doing db job with scraped data file']
    log(log_msgs,level=logging.INFO)
    ## 파일 리스트 생성
    db_cnt = 0
    files = get_crawled_file_list(scrap_dir)
    ## 각 파일 처리
    for file in files:
        log(file,level=logging.DEBUG)
        csv_file = scrap_dir+'/'+file
        head, raw_data = read_crawled_file(csv_file,csv=True)
        ## 스키마 체크 - 차후 오류 로그 체크하여 해당 내용 확인후 반영
        ## DB 처리
        log('execute insert query',level=logging.DEBUG)
        i_cnt = scraped_csv_to_db(head,raw_data,db)
        log(['insert result',i_cnt],level=logging.DEBUG)
        db_cnt += i_cnt
        ## 정상 처리 파일 처리
        if i_cnt > 0:
            move_scraped_file(csv_file,db_ok_dir)
    end_time = datetime.today()
    log_msgs = ['end batch job','doing db job with scraped data file',
                'elapsed -{}'.format(end_time-start_time),'Total :{} rows inserted.'.format(db_cnt)]
    log(log_msgs,level=logging.INFO)
    
def scraped_csv_to_db(head,raw_data,db):
    log('$$ check csv to db process.',level=logging.INFO)
    ## CSV 파일 읽기
    csv_data = csv.reader(io.StringIO(raw_data))
    ## DB 처리 리스트 생성
    target_list = []
    for d in csv_data:
        ## scrap_date, scrap_site, patten(1 편도)
        td_list = [head['crawl_date'],head['site_code'],'1']
        ## airline,flt,dpt,arr,dpt_time,arr_time,fare,tax1,tax2,seat
        td_list.extend(d)
        target_list.append(td_list)
    ## DB 처리
    cnt = 0
    conn = sqlite3.connect(db)
    try:
        cur = conn.cursor()
        sql = "insert into airfare_scraped_data"+\
        "(scrap_date,scrap_site,patten,airline,flt,dpt_date,dpt,arr,dpt_time,arr_time,fare,tax1,tax2,seat)"+\
        "values(?,?,?,?,?,?,?,?,?,?,?,?,?,?)"
        cur.executemany(sql,target_list)
        conn.commit()
        cnt = len(target_list)
    except sqlite3.Error as e:
        if conn:
            conn.rollback()
        log(e,level=logging.ERROR)
        cnt = 0
    finally:
        if conn:
            conn.close()
    log('$$ check db process result : {}'.format(cnt),level=logging.INFO)
    return cnt

## 스크랩 처리후 남은 파일 처리 - 필요없는 파일 nodata 폴더로 이동
## csv 파일 삭제 처리
def move_nodata_files():
    src = CRAWL_DIR
    dst = NODATA_DIR
    print('start moving error files')
    nodata_files = get_files(src,check='scrap')
    print('nodata files : ',len(nodata_files))
    for f in nodata_files:
        move_file(os.path.join('crawl', f),dst)
    print('end moving error files')
    ## csv 파일 데이터 삭제 처리
    for file in get_files(SCRAP_DATA_DIR):
        os.remove('scrap_data/'+file)

# %%
dom_int = None # 0 - 국내선, 1 - 국제선, None - 모두
batch_scrap(CRAWL_DIR,SCRAP_DATA_DIR,dom_int=dom_int)

batch_cnt = 3
db_file = 'airfare_scraped_data.db'
for i in range(batch_cnt):
    batch_error(CRAWL_DIR)
    batch_scrap(CRAWL_DIR,SCRAP_DATA_DIR,dom_int=dom_int)
batch_db(SCRAP_DATA_DIR,DB_OK_DIR,db_file)
# Out:
# 2017-08-14 08:58:22,950 root     INFO     start batch job :: scraping crawled file
# 2017-08-14 08:58:22,991 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170815.txt
# 2017-08-14 08:58:22,997 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,000 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,009 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,024 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170816.txt
# 2017-08-14 08:58:23,028 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,032 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,035 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,057 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170817.txt
# 2017-08-14 08:58:23,063 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,068 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,071 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,087 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170818.txt
# 2017-08-14 08:58:23,091 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,095 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,108 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,132 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170819.txt
# 2017-08-14 08:58:23,139 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,144 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,151 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,171 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170820.txt
# 2017-08-14 08:58:23,182 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,186 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,190 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,207 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170821.txt
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# 2017-08-14 08:58:23,219 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,222 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,226 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,244 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170822.txt
# 2017-08-14 08:58:23,250 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,252 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,255 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,268 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170823.txt
# 2017-08-14 08:58:23,276 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,278 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,281 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,301 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170824.txt
# 2017-08-14 08:58:23,305 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,308 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,314 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,333 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170825.txt
# 2017-08-14 08:58:23,339 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,341 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,345 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,369 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170826.txt
# 2017-08-14 08:58:23,372 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,378 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,381 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,401 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170827.txt
# 2017-08-14 08:58:23,405 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,408 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,414 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,430 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170828.txt
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# 2017-08-14 08:58:23,440 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,443 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,446 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,465 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170829.txt
# 2017-08-14 08:58:23,469 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,473 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,475 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,552 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170830.txt
# 2017-08-14 08:58:23,556 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,562 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,566 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,588 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170831.txt
# 2017-08-14 08:58:23,600 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,621 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,639 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# 2017-08-14 08:58:23,686 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170901.txt
# 2017-08-14 08:58:23,692 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,694 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,699 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,713 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170902.txt
# 2017-08-14 08:58:23,717 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,721 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,724 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,763 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170903.txt
# 2017-08-14 08:58:23,769 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,773 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,776 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,793 root     DEBUG    scrap_2017081408_7C_7C_BKK_ICN_20170904.txt
# 2017-08-14 08:58:23,801 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,806 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,811 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,828 root     DEBUG    scrap_2017081408_7C_7C_FUK_ICN_20170815.txt
# 2017-08-14 08:58:23,837 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,840 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,843 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# start scraping jejuair crawled data
# end scraping jejuair crawled data
# 2017-08-14 08:58:23,862 root     DEBUG    scrap_2017081408_7C_7C_FUK_ICN_20170816.txt
# 2017-08-14 08:58:23,870 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,873 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,876 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,892 root     DEBUG    scrap_2017081408_7C_7C_FUK_ICN_20170817.txt
# 2017-08-14 08:58:23,897 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,903 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,906 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,930 root     DEBUG    scrap_2017081408_7C_7C_FUK_ICN_20170818.txt
# 2017-08-14 08:58:23,938 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:23,941 root     DEBUG    1 :: 7C :: scraping_7C_int
# 2017-08-14 08:58:23,947 root     DEBUG    check func :: <function scraping_7C_int at 0x0000000007F837B8>
# 2017-08-14 08:58:23,991 root     DEBUG    scrap_2017081408_7C_7C_FUK_ICN_20170819.txt
# 2017-08-14 08:58:23,997 root     DEBUG    1 :: 7C
# 2017-08-14 08:58:24
root     DEBUG    start scraping Interpark crawled data
# 2017-08-14 08:58:29,390 root     DEBUG    end scraping Interpark crawled data
# 2017-08-14 08:58:29,409 root     DEBUG    scrap_2017081408_IP_7C_CJU_GMP_20170822.txt
# 2017-08-14 08:58:29,419 root     DEBUG    0 :: IP
# 2017-08-14 08:58:29,424 root     DEBUG    0 :: IP :: scraping_IP_dom
# 2017-08-14 08:58:29,433 root     DEBUG    check func :: <function scraping_IP_dom at 0x00000000058A9A60>
# 2017-08-14 08:58:29,436 root     DEBUG    start scraping Interpark crawled data
# 2017-08-14 08:58:29,461 root     DEBUG    end scraping Interpark crawled data
# 2017-08-14 08:58:29,474 root     DEBUG    scrap_2017081408_IP_7C_CJU_GMP_20170823.txt
# 2017-08-14 08:58:29,497 root     DEBUG    0 :: IP
# 2017-08-14 08:58:29,503 root     DEBUG    0 :: IP :: scraping_IP_dom
# 2017-08-14 08:58:29,507 root     DEBUG    check func :: <function scraping_IP_dom at 0x00000000058A9A60>
# 2017-08-14 08:58:29,510 root     DEBUG    start scraping Interpark crawled data
# ...
# 2017-08-14 09:05:42,816 root     DEBUG    execute insert query
# 2017-08-14 09:05:42,821 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:42,845 root     INFO     $$ check db process result : 6
# 2017-08-14 09:05:42,849 root     DEBUG    insert result :: 6
# 2017-08-14 09:05:42,861 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170815.csv
# 2017-08-14 09:05:42,866 root     DEBUG    execute insert query
# 2017-08-14 09:05:42,870 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:42,891 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:42,897 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:42,910 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170816.csv
# 2017-08-14 09:05:42,915 root     DEBUG    execute insert query
# 2017-08-14 09:05:42,919 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:42,940 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:42,945 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:42,959 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170817.csv
# 2017-08-14 09:05:42,964 root     DEBUG    execute insert query
# 2017-08-14 09:05:42,969 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:42,994 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:42,998 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,011 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170818.csv
# 2017-08-14 09:05:43,016 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,019 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:43,043 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:43,047 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,058 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170819.csv
# 2017-08-14 09:05:43,064 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,071 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:43,092 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:43,144 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,157 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170820.csv
# 2017-08-14 09:05:43,167 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,172 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:43,194 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:43,202 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,213 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170821.csv
# 2017-08-14 09:05:43,222 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,226 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:43,251 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:43,264 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,276 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170822.csv
# 2017-08-14 09:05:43,281 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,286 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:43,310 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:43,314 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,323 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170823.csv
# 2017-08-14 09:05:43,328 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,332 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:43,357 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:43,361 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,370 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170824.csv
# 2017-08-14 09:05:43,378 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,382 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:43,406 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:43,410 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,419 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170825.csv
# 2017-08-14 09:05:43,426 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,430 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:43,456 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:43,460 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,473 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170826.csv
# 2017-08-14 09:05:43,479 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,483 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:43,509 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:43,514 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,528 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170827.csv
# 2017-08-14 09:05:43,537 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,541 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:43,569 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:43,573 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,583 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170828.csv
# 2017-08-14 09:05:43,590 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,594 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:43,618 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:43,622 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,632 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170829.csv
# 2017-08-14 09:05:43,638 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,642 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:43,677 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:43,684 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,699 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170830.csv
# 2017-08-14 09:05:43,704 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,708 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:43,732 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:43,739 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,750 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170831.csv
# 2017-08-14 09:05:43,755 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,760 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:43,786 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:43,790 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,799 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170901.csv
# 2017-08-14 09:05:43,805 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,809 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:43,836 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:43,841 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,848 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170902.csv
# 2017-08-14 09:05:43,852 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,854 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:43,871 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:43,874 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,881 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170903.csv
# 2017-08-14 09:05:43,887 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,890 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:43,910 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:43,913 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,919 root     DEBUG    scrap_2017081408_ZE_ZE_FUK_ICN_20170904.csv
# 2017-08-14 09:05:43,923 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,926 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:43,977 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:43,981 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:43,988 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170815.csv
# 2017-08-14 09:05:43,993 root     DEBUG    execute insert query
# 2017-08-14 09:05:43,996 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,013 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:44,018 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:44,025 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170816.csv
# 2017-08-14 09:05:44,030 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,033 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,050 root     INFO     $$ check db process result : 6
# 2017-08-14 09:05:44,053 root     DEBUG    insert result :: 6
# 2017-08-14 09:05:44,063 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170817.csv
# 2017-08-14 09:05:44,066 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,068 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,082 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:44,087 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:44,094 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170818.csv
# 2017-08-14 09:05:44,098 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,101 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,118 root     INFO     $$ check db process result : 6
# 2017-08-14 09:05:44,122 root     DEBUG    insert result :: 6
# 2017-08-14 09:05:44,131 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170819.csv
# 2017-08-14 09:05:44,137 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,140 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,156 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:44,160 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:44,169 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170820.csv
# 2017-08-14 09:05:44,173 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,176 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,193 root     INFO     $$ check db process result : 6
# 2017-08-14 09:05:44,198 root     DEBUG    insert result :: 6
# 2017-08-14 09:05:44,205 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170821.csv
# 2017-08-14 09:05:44,209 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,211 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,224 root     INFO     $$ check db process result : 6
# 2017-08-14 09:05:44,227 root     DEBUG    insert result :: 6
# 2017-08-14 09:05:44,234 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170822.csv
# 2017-08-14 09:05:44,240 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,243 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,276 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:44,285 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:44,293 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170823.csv
# 2017-08-14 09:05:44,313 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,317 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,336 root     INFO     $$ check db process result : 6
# 2017-08-14 09:05:44,341 root     DEBUG    insert result :: 6
# 2017-08-14 09:05:44,355 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170824.csv
# 2017-08-14 09:05:44,359 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,363 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,383 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:44,387 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:44,400 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170825.csv
# 2017-08-14 09:05:44,405 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,408 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,428 root     INFO     $$ check db process result : 6
# 2017-08-14 09:05:44,433 root     DEBUG    insert result :: 6
# 2017-08-14 09:05:44,441 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170826.csv
# 2017-08-14 09:05:44,447 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,449 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,472 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:44,475 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:44,483 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170827.csv
# 2017-08-14 09:05:44,487 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,490 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,508 root     INFO     $$ check db process result : 6
# 2017-08-14 09:05:44,512 root     DEBUG    insert result :: 6
# 2017-08-14 09:05:44,519 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170828.csv
# 2017-08-14 09:05:44,524 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,527 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,547 root     INFO     $$ check db process result : 6
# 2017-08-14 09:05:44,551 root     DEBUG    insert result :: 6
# 2017-08-14 09:05:44,560 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170829.csv
# 2017-08-14 09:05:44,565 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,567 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,587 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:44,592 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:44,600 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170830.csv
# 2017-08-14 09:05:44,604 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,606 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,626 root     INFO     $$ check db process result : 6
# 2017-08-14 09:05:44,629 root     DEBUG    insert result :: 6
# 2017-08-14 09:05:44,639 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170831.csv
# 2017-08-14 09:05:44,643 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,645 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,663 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:44,665 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:44,672 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170901.csv
# 2017-08-14 09:05:44,681 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,687 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,707 root     INFO     $$ check db process result : 6
# 2017-08-14 09:05:44,710 root     DEBUG    insert result :: 6
# 2017-08-14 09:05:44,717 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170902.csv
# 2017-08-14 09:05:44,721 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,724 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,742 root     INFO     $$ check db process result : 9
# 2017-08-14 09:05:44,745 root     DEBUG    insert result :: 9
# 2017-08-14 09:05:44,758 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170903.csv
# 2017-08-14 09:05:44,761 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,764 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,799 root     INFO     $$ check db process result : 6
# 2017-08-14 09:05:44,802 root     DEBUG    insert result :: 6
# 2017-08-14 09:05:44,810 root     DEBUG    scrap_2017081408_ZE_ZE_NRT_ICN_20170904.csv
# 2017-08-14 09:05:44,813 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,817 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,836 root     INFO     $$ check db process result : 6
# 2017-08-14 09:05:44,842 root     DEBUG    insert result :: 6
# 2017-08-14 09:05:44,854 root     DEBUG    scrap_2017081409_IP_OZ_CJU_CJJ_20170816.csv
# 2017-08-14 09:05:44,864 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,885 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,915 root     INFO     $$ check db process result : 6
# 2017-08-14 09:05:44,921 root     DEBUG    insert result :: 6
# 2017-08-14 09:05:44,931 root     DEBUG    scrap_2017081409_IP_OZ_GMP_PUS_20170816.csv
# 2017-08-14 09:05:44,936 root     DEBUG    execute insert query
# 2017-08-14 09:05:44,940 root     INFO     $$ check csv to db process.
# 2017-08-14 09:05:44,963 root     INFO     $$ check db process result : 28
# 2017-08-14 09:05:44,973 root     DEBUG    insert result :: 28
# 2017-08-14 09:05:44,991 root     INFO     end batch job :: doing db job with scraped data file :: elapsed -0:01:10.458030 :: Total :27715 rows inserted.

# %%
## 추가 오류 처리 진행시
dom_int = None
db_file = 'airfare_scraped_data.db'
batch_error(CRAWL_DIR)
batch_scrap(CRAWL_DIR,SCRAP_DATA_DIR,dom_int=dom_int)
batch_db(SCRAP_DATA_DIR,DB_OK_DIR,db_file)

# %%
## 스크랩 잔존 파일 이동 처리, CSV 파일 삭제
move_nodata_files()
# Out:
# start moving error files
# nodata files :  59
# end moving error files

# %%
db_file = 'airfare_scraped_data.db'
batch_db(SCRAP_DATA_DIR,DB_OK_DIR,db_file)
